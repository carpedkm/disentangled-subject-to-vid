# %%
pth = "/mnt/carpedkm_data/pexels_8fps_latents_1600"

# %%
import numpy as np
import os
from tqdm import tqdm

# %%
npys = os.listdir(pth)

# %%
for npf in tqdm(npys):
    if not npf.endswith(".npy"):
        continue
    # print(npf)
    npfpth = os.path.join(pth, npf)
    arr = np.load(npfpth)
    if arr.shape != (1, 16, 13, 60, 90):
        print("bad shape", arr.shape)
        continue
    
print('done')
# Out:
# ...
# 100%|██████████| 1600/1600 [02:22<00:00, 11.23it/s]
# done

# %%
from datasets import load_dataset
import numpy as np

# Load the dataset (the same path you used before)
dataset = load_dataset("/root/daneul/projects/refactored/CogVideo/Subjects200K_collection3")["train"]

# Get a single item
sample = dataset[0]  # or any index

# Retrieve the PIL Image
pil_img = sample["image"]

# Convert to NumPy array to get the shape as (H, W, C)
img_array = np.array(pil_img)
print("Image shape (H, W, C):", img_array.shape)
# Out:
# Image shape (H, W, C): (1024, 2048, 3)

# %%
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2048x1024>
