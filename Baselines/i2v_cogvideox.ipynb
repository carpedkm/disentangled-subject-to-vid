# %%
import torch
from diffusers import CogVideoXImageToVideoPipeline
from diffusers.utils import export_to_video, load_image, export_to_video_with_frames

prompt = "A cat is riding a rollerblade"
image = load_image(image="/root/daneul/projects/refactored/CogVideo/Baselines/val_samples_im/cat.png")
pipe = CogVideoXImageToVideoPipeline.from_pretrained(
    "THUDM/CogVideoX-5b-I2V",
    torch_dtype=torch.bfloat16
)

pipe.enable_sequential_cpu_offload()
pipe.vae.enable_tiling()
pipe.vae.enable_slicing()

video = pipe(
    prompt=prompt,
    image=image,
    num_videos_per_prompt=1,
    num_inference_steps=50,
    num_frames=5,
    guidance_scale=6,
    generator=torch.Generator(device="cuda").manual_seed(42),
).frames[0]

export_to_video(video, "output.mp4", fps=8)
export_to_video_with_frames(video, 'output.mp4', 'output_frames', fps=8, eval_mode=True)
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  2.34it/s]
# Loading checkpoint shards: 100%|██████████| 3/3 [00:00<00:00, 49.96it/s]it/s]
# Loading pipeline components...: 100%|██████████| 5/5 [00:01<00:00,  3.83it/s]
# 100%|██████████| 50/50 [01:21<00:00,  1.62s/it]
# 'output.mp4'

# %%
import json
import os

from tqdm import tqdm
from PIL import Image
import torch
from diffusers import CogVideoXImageToVideoPipeline
from diffusers.utils import export_to_video, load_image, export_to_video_with_frames

# %%
prompt_path = "/root/daneul/projects/refactored/CogVideo/Pexels_subset_100K_fps8_flow-25-50_sample500/small/metadata.jsonl"
type_to_eval = "small" # medium, large
first_frame_path = "/root/daneul/projects/refactored/CogVideo/Pexels_subset_100K_fps8_flow-25-50_sample500/small/first_frame"
video_save_path = "/root/daneul/projects/refactored/CogVideo/Baselines/I2V_baseline/Temporal_eval"
sampling_count = 100

# %%
pipe = CogVideoXImageToVideoPipeline.from_pretrained(
    "THUDM/CogVideoX-5b-I2V",
    torch_dtype=torch.bfloat16
)

pipe.enable_sequential_cpu_offload()
pipe.vae.enable_tiling()
pipe.vae.enable_slicing()
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  2.44it/s]
# Loading checkpoint shards: 100%|██████████| 3/3 [00:00<00:00, 48.88it/s]it/s]
# Loading pipeline components...: 100%|██████████| 5/5 [00:01<00:00,  2.96it/s]

# %%
# load path jsonl
with open(prompt_path, "r") as f:
    lines = f.readlines()
    meta_list = [line for line in lines]
# make meta dict 
meta_dict = {}
meta_list = []
with open(prompt_path, 'r') as f:
    for line in f:
        try:
            meta_list.append(json.loads(line))
        except:
            print('Error in loading json')
meta_dict = {}
for meta in meta_list:
    vid_id = str(meta['video_latent_path'].split('/')[-1].split('.')[0])
    meta_dict[vid_id] = meta
# get input image list
image_list = os.listdir(first_frame_path)

for i in tqdm(range(sampling_count)):
    vid_id = str(image_list[i].split(".")[0])
    input_image = os.path.join(first_frame_path, image_list[i])
    prompt = meta_dict[vid_id]["prompt"]
    input_image = Image.open(input_image)
    # pass through I2V
    video = pipe(
        prompt=prompt,
        image=input_image,
        num_videos_per_prompt=1,
        num_inference_steps=50,
        num_frames=5,
        guidance_scale=6,
        generator=torch.Generator(device="cuda").manual_seed(42),
    ).frames[0]
    save_path = os.path.join(video_save_path, f"{i}.mp4")
    frames_save_path = os.path.join(video_save_path, type_to_eval, "video_frames")
    export_to_video_with_frames(video, save_path, frames_save_path, fps=8, eval_mode=True)
# Out:
#   4%|▍         | 2/50 [00:18<07:27,  9.32s/it]
#   0%|          | 0/100 [00:21<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 27
#      25 input_image = Image.open(input_image)
#      26 # pass through I2V
# ---> 27 video = pipe(
#      28     prompt=prompt,
#      29     image=input_image,
#      30     num_videos_per_prompt=1,
#      31     num_inference_steps=50,
#      32     num_frames=49,
#      33     guidance_scale=6,
#      34     generator=torch.Generator(device="cuda").manual_seed(42),
#      35 ).frames[0]
#      36 save_path = os.path.join(video_save_path, f"{i}.mp4")
#      37 frames_save_path = os.path.join(video_save_path, type_to_eval, "video_frames")
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/daneul/projects/refactored/diffusers/src/diffusers/pipelines/cogvideo/pipeline_cogvideox_image2video.py:834, in CogVideoXImageToVideoPipeline.__call__(self, image, prompt, negative_prompt, height, width, num_frames, num_inference_steps, timesteps, guidance_scale, use_dynamic_cfg, num_videos_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, output_type, return_dict, attention_kwargs, callback_on_step_end, callback_on_step_end_tensor_inputs, max_sequence_length)
#     831 timestep = t.expand(latent_model_input.shape[0])
#     833 # predict noise model_output
# --> 834 noise_pred = self.transformer(
#     835     hidden_states=latent_model_input,
#     836     encoder_hidden_states=prompt_embeds,
#     837     timestep=timestep,
#     838     ofs=ofs_emb,
#     839     image_rotary_emb=image_rotary_emb,
#     840     attention_kwargs=attention_kwargs,
#     841     return_dict=False,
#     842 )[0]
#     843 noise_pred = noise_pred.float()
#     845 # perform guidance
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/accelerate/hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     168         output = module._old_forward(*args, **kwargs)
#     169 else:
# --> 170     output = module._old_forward(*args, **kwargs)
#     171 return module._hf_hook.post_forward(module, output)
#
# File ~/daneul/projects/refactored/diffusers/src/diffusers/models/transformers/cogvideox_transformer_3d.py:498, in CogVideoXTransformer3DModel.forward(self, hidden_states, encoder_hidden_states, timestep, timestep_cond, ofs, image_rotary_emb, attention_kwargs, return_dict)
#     489         hidden_states, encoder_hidden_states = self._gradient_checkpointing_func(
#     490             block,
#     491             hidden_states,
#    (...)
#     495             attention_kwargs,
#     496         )
#     497     else:
# --> 498         hidden_states, encoder_hidden_states = block(
#     499             hidden_states=hidden_states,
#     500             encoder_hidden_states=encoder_hidden_states,
#     501             temb=emb,
#     502             image_rotary_emb=image_rotary_emb,
#     503             attention_kwargs=attention_kwargs,
#     504         )
#     506 hidden_states = self.norm_final(hidden_states)
#     508 # 4. Final block
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/daneul/projects/refactored/diffusers/src/diffusers/models/transformers/cogvideox_transformer_3d.py:135, in CogVideoXBlock.forward(self, hidden_states, encoder_hidden_states, temb, image_rotary_emb, attention_kwargs)
#     130 norm_hidden_states, norm_encoder_hidden_states, gate_msa, enc_gate_msa = self.norm1(
#     131     hidden_states, encoder_hidden_states, temb
#     132 )
#     134 # attention
# --> 135 attn_hidden_states, attn_encoder_hidden_states = self.attn1(
#     136     hidden_states=norm_hidden_states,
#     137     encoder_hidden_states=norm_encoder_hidden_states,
#     138     image_rotary_emb=image_rotary_emb,
#     139     **attention_kwargs,
#     140 )
#     142 hidden_states = hidden_states + gate_msa * attn_hidden_states
#     143 encoder_hidden_states = encoder_hidden_states + enc_gate_msa * attn_encoder_hidden_states
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/daneul/projects/refactored/diffusers/src/diffusers/models/attention_processor.py:601, in Attention.forward(self, hidden_states, encoder_hidden_states, attention_mask, **cross_attention_kwargs)
#     596     logger.warning(
#     597         f"cross_attention_kwargs {unused_kwargs} are not expected by {self.processor.__class__.__name__} and will be ignored."
#     598     )
#     599 cross_attention_kwargs = {k: w for k, w in cross_attention_kwargs.items() if k in attn_parameters}
# --> 601 return self.processor(
#     602     self,
#     603     hidden_states,
#     604     encoder_hidden_states=encoder_hidden_states,
#     605     attention_mask=attention_mask,
#     606     **cross_attention_kwargs,
#     607 )
#
# File ~/daneul/projects/refactored/diffusers/src/diffusers/models/attention_processor.py:2872, in CogVideoXAttnProcessor2_0.__call__(self, attn, hidden_states, encoder_hidden_states, attention_mask, image_rotary_emb)
#    2869 hidden_states = hidden_states.transpose(1, 2).reshape(batch_size, -1, attn.heads * head_dim)
#    2871 # linear proj
# -> 2872 hidden_states = attn.to_out[0](hidden_states)
#    2873 # dropout
#    2874 hidden_states = attn.to_out[1](hidden_states)
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/accelerate/hooks.py:165, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164 def new_forward(module, *args, **kwargs):
# --> 165     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     166     if module._hf_hook.no_grad:
#     167         with torch.no_grad():
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/accelerate/hooks.py:355, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     347         if (
#     348             value is not None
#     349             and self.tied_params_map is not None
#     350             and value.data_ptr() in self.tied_params_map
#     351             and self.execution_device not in self.tied_params_map[value.data_ptr()]
#     352         ):
#     353             self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
# --> 355         set_module_tensor_to_device(
#     356             module,
#     357             name,
#     358             self.execution_device,
#     359             value=value,
#     360             fp16_statistics=fp16_statistics,
#     361             tied_params_map=self.tied_params_map,
#     362         )
#     364 return send_to_device(args, self.execution_device), send_to_device(
#     365     kwargs, self.execution_device, skip_keys=self.skip_keys
#     366 )
#
# File /opt/conda/envs/cogvideox_van/lib/python3.12/site-packages/accelerate/utils/modeling.py:330, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     328             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     329 elif isinstance(value, torch.Tensor):
# --> 330     new_value = value.to(device)
#     331 else:
#     332     new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:

# %%
with open(prompt_path, "r") as f:
    lines = f.readlines()
    meta_list = [line for line in lines]
# make meta dict 
meta_dict = {}
for i in meta_list:
    vid_id = str(i.split("/")[-1].split(".")[0])
    meta_dict[vid_id] = i

# %%
meta_dict
# Out:
# {'17778020': '{"video_latent_path": "video_latent/17778020.npy", "first_frame_latent_path": "first_frame_latent/17778020.npy", "prompt": "A musician in a red sweater is captured mid-movement playing a violin against a plain backdrop."}\n',
#  '7999352': '{"video_latent_path": "video_latent/7999352.npy", "first_frame_latent_path": "first_frame_latent/7999352.npy", "prompt": "Lush green hillsides blanketed in dense forests, a winding road cutting through the grassy meadow, and a lone cabin resting in the peaceful valley."}\n',
#  '5561378': '{"video_latent_path": "video_latent/5561378.npy", "first_frame_latent_path": "first_frame_latent/5561378.npy", "prompt": "A person with shoulder-length hair is wearing a satin outfit, standing in a room with a blurred background suggesting motion or activity."}\n',
#  '7131718': '{"video_latent_path": "video_latent/7131718.npy", "first_frame_latent_path": "first_frame_latent/7131718.npy", "prompt": "man wearing a vest"}\n',
#  '6250029': '{"video_latent_path": "video_latent/6250029.npy", "first_frame_latent_path": "first_frame_latent/6250029.npy", "prompt": "close up video of a person shaving beard"}\n',
#  '12717007': '{"video_latent_path": "video_latent/12717007.npy", "first_frame_latent_path": "first_frame_latent/12717007.npy", "prompt": "a person lighting candles"}\n',
#  '6602698': '{"video_latent_path": "video_latent/6602698.npy", "first_frame_latent_path": "first_frame_latent/6602698.npy", "prompt": "overhead shot of fishes swimming in crystal clear water"}\n',
#  '6627967': '{"video_latent_path": "video_latent/6627967.npy", "first_frame_latent_path": "first_frame_latent/6627967.npy", "prompt": "two women walking in the park while talking"}\n',
#  '8135553': '{"video_latent_path": "video_latent/8135553.npy", "first_frame_latent_path": "first_frame_latent/8135553.npy", "prompt": "a woman listening to a man lying on a sofa"}\n',
#  '8375411': '{"video_latent_path": "video_latent/8375411.npy", "first_frame_latent_path": "first_frame_latent/8375411.npy", "prompt": "a man playing the guitar"}\n',
#  '11112324': '{"video_latent_path": "video_latent/11112324.npy", "first_frame_latent_path": "first_frame_latent/11112324.npy", "prompt": "woman writing on her notebook"}\n',
#  '7550187': '{"video_latent_path": "video_latent/7550187.npy", "first_frame_latent_path": "first_frame_latent/7550187.npy", "prompt": "woman walking on the grass field and taking photos"}\n',
#  '8134975': '{"video_latent_path": "video_latent/8134975.npy", "first_frame_latent_path": "first_frame_latent/8134975.npy", "prompt": "close up of a person stirring paint in a ceramic cup"}\n',
#  '7161354': '{"video_latent_path": "video_latent/7161354.npy", "first_frame_latent_path": "first_frame_latent/7161354.npy", "prompt": "Three individuals stand before a flowing curtain in a golden field, exuding a sense of casual fashion and tranquility."}\n',
#  '6905143': '{"video_latent_path": "video_latent/6905143.npy", "first_frame_latent_path": "first_frame_latent/6905143.npy", "prompt": "woman seated on rock while observing sea horizon"}\n',
#  '3825762': '{"video_latent_path": "video_latent/3825762.npy", "first_frame_latent_path": "first_frame_latent/3825762.npy", "prompt": "A person is captured in dynamic motion, casting a shadow on a pink-hued wall illuminated by a projector\'s light."}\n',
#  '4947342': '{"video_latent_path": "video_latent/4947342.npy", "first_frame_latent_path": "first_frame_latent/4947342.npy", "prompt": "a man whispering to a woman"}\n',
#  '7505339': '{"video_latent_path": "video_latent/7505339.npy", "first_frame_latent_path": "first_frame_latent/7505339.npy", "prompt": "a woman pastor kneeling in front of the altar"}\n',
#  '14049518': '{"video_latent_path": "video_latent/14049518.npy", "first_frame_latent_path": "first_frame_latent/14049518.npy", "prompt": "A vast expanse of lush green forests blankets the rolling hills, while a small township nestles in the valley below."}\n',
#  '6951135': '{"video_latent_path": "video_latent/6951135.npy", "first_frame_latent_path": "first_frame_latent/6951135.npy", "prompt": "woman wearing hijab and face mask"}\n',
#  '7767455': '{"video_latent_path": "video_latent/7767455.npy", "first_frame_latent_path": "first_frame_latent/7767455.npy", "prompt": "a man and a boy standing and looking in the camera behind a truck"}\n',
#  '2377136': '{"video_latent_path": "video_latent/2377136.npy", "first_frame_latent_path": "first_frame_latent/2377136.npy", "prompt": "ripples on water surface"}\n',
#  '4712476': '{"video_latent_path": "video_latent/4712476.npy", "first_frame_latent_path": "first_frame_latent/4712476.npy", "prompt": "landmark skyline architecture travel"}\n',
#  '5320108': '{"video_latent_path": "video_latent/5320108.npy", "first_frame_latent_path": "first_frame_latent/5320108.npy", "prompt": "an aerial footage of a woman standing on a rocky cliff"}\n',
#  '6168548': '{"video_latent_path": "video_latent/6168548.npy", "first_frame_latent_path": "first_frame_latent/6168548.npy", "prompt": "The picture shows a tranquil beach scene with calm waters reflecting the dramatic clouds and colorful sky at sunset."}\n',
#  '9489384': '{"video_latent_path": "video_latent/9489384.npy", "first_frame_latent_path": "first_frame_latent/9489384.npy", "prompt": "a woman discussing a document to her colleagues"}\n',
#  '4718191': '{"video_latent_path": "video_latent/4718191.npy", "first_frame_latent_path": "first_frame_latent/4718191.npy", "prompt": "close up video of a man laughing"}\n',
#  '10289663': '{"video_latent_path": "video_latent/10289663.npy", "first_frame_latent_path": "first_frame_latent/10289663.npy", "prompt": "blowing a birthday cake"}\n',
#  '3580088': '{"video_latent_path": "video_latent/3580088.npy", "first_frame_latent_path": "first_frame_latent/3580088.npy", "prompt": "two young women looking at dresses in a store"}\n',
#  '11032947': '{"video_latent_path": "video_latent/11032947.npy", "first_frame_latent_path": "first_frame_latent/11032947.npy", "prompt": "drone footage of a circular storage tank"}\n',
#  '4203482': '{"video_latent_path": "video_latent/4203482.npy", "first_frame_latent_path": "first_frame_latent/4203482.npy", "prompt": "a sad man looking at a picture"}\n',
#  '6533830': '{"video_latent_path": "video_latent/6533830.npy", "first_frame_latent_path": "first_frame_latent/6533830.npy", "prompt": "man taking selfie with his dog"}\n',
#  '7330832': '{"video_latent_path": "video_latent/7330832.npy", "first_frame_latent_path": "first_frame_latent/7330832.npy", "prompt": "a volcano peak covered in snow"}\n',
#  '6415589': '{"video_latent_path": "video_latent/6415589.npy", "first_frame_latent_path": "first_frame_latent/6415589.npy", "prompt": "blond woman dancing on wind"}\n',
#  '6282951': '{"video_latent_path": "video_latent/6282951.npy", "first_frame_latent_path": "first_frame_latent/6282951.npy", "prompt": "waiter bringing coffee shop menu to young women"}\n',
#  '4288026': '{"video_latent_path": "video_latent/4288026.npy", "first_frame_latent_path": "first_frame_latent/4288026.npy", "prompt": "a man holding the arm of a woman"}\n',
#  '15384197': '{"video_latent_path": "video_latent/15384197.npy", "first_frame_latent_path": "first_frame_latent/15384197.npy", "prompt": "A cozy scene featuring a hand holding a mug of tea, a vintage camera, and books, surrounded by twinkling lights and a knit blanket."}\n',
#  '11865314': '{"video_latent_path": "video_latent/11865314.npy", "first_frame_latent_path": "first_frame_latent/11865314.npy", "prompt": "girl jumping on a sofa"}\n',
#  '5761037': '{"video_latent_path": "video_latent/5761037.npy", "first_frame_latent_path": "first_frame_latent/5761037.npy", "prompt": "kids reading a book together on a bed"}\n',
#  '7316627': '{"video_latent_path": "video_latent/7316627.npy", "first_frame_latent_path": "first_frame_latent/7316627.npy", "prompt": "two children reading a book together"}\n',
#  '8487470': '{"video_latent_path": "video_latent/8487470.npy", "first_frame_latent_path": "first_frame_latent/8487470.npy", "prompt": "girls in a ballet class"}\n',
#  '3826732': '{"video_latent_path": "video_latent/3826732.npy", "first_frame_latent_path": "first_frame_latent/3826732.npy", "prompt": "people on the band playing a music"}\n',
#  '6153590': '{"video_latent_path": "video_latent/6153590.npy", "first_frame_latent_path": "first_frame_latent/6153590.npy", "prompt": "a man doing exercise"}\n',
#  '6967849': '{"video_latent_path": "video_latent/6967849.npy", "first_frame_latent_path": "first_frame_latent/6967849.npy", "prompt": "toy plane flying against fluffy clouds in blue sky"}\n',
#  '8042504': '{"video_latent_path": "video_latent/8042504.npy", "first_frame_latent_path": "first_frame_latent/8042504.npy", "prompt": "music teacher and a boy playing electronic keyboard together"}\n',
#  '16123671': '{"video_latent_path": "video_latent/16123671.npy", "first_frame_latent_path": "first_frame_latent/16123671.npy", "prompt": "an aerial footage of town in brazil"}\n',
#  '5547221': '{"video_latent_path": "video_latent/5547221.npy", "first_frame_latent_path": "first_frame_latent/5547221.npy", "prompt": "A group of people are gathered around a table, engaging in a game of dominoes, with hands in motion and a hint of a cozy indoor setting."}\n',
#  '10904737': '{"video_latent_path": "video_latent/10904737.npy", "first_frame_latent_path": "first_frame_latent/10904737.npy", "prompt": "timelapse of wind turbines during sunset"}\n',
#  '8438518': '{"video_latent_path": "video_latent/8438518.npy", "first_frame_latent_path": "first_frame_latent/8438518.npy", "prompt": "a woman making a crepe"}\n',
#  '12267947': '{"video_latent_path": "video_latent/12267947.npy", "first_frame_latent_path": "first_frame_latent/12267947.npy", "prompt": "drone footage of the sea"}\n',
#  '6952086': '{"video_latent_path": "video_latent/6952086.npy", "first_frame_latent_path": "first_frame_latent/6952086.npy", "prompt": "people exercising on a cliff of a mountain"}\n',
#  '9732069': '{"video_latent_path": "video_latent/9732069.npy", "first_frame_latent_path": "first_frame_latent/9732069.npy", "prompt": "man with backpack in forest in winter"}\n',
#  '6825108': '{"video_latent_path": "video_latent/6825108.npy", "first_frame_latent_path": "first_frame_latent/6825108.npy", "prompt": "An assortment of fashion accessories, including sunglasses, watches, bow ties, and scrunchies, is artistically arranged on a white surface."}\n',
#  '13177015': '{"video_latent_path": "video_latent/13177015.npy", "first_frame_latent_path": "first_frame_latent/13177015.npy", "prompt": "Stacked in a pile, a green passport reading \'Republic of China\' lays on top of a maroon passport with an emblem."}\n',
#  '9964985': '{"video_latent_path": "video_latent/9964985.npy", "first_frame_latent_path": "first_frame_latent/9964985.npy", "prompt": "people talking while drinking champagne"}\n',
#  '3859452': '{"video_latent_path": "video_latent/3859452.npy", "first_frame_latent_path": "first_frame_latent/3859452.npy", "prompt": "Two pairs of legs, one male and one female, appear planted on the floor under a table near a window."}\n',
#  '4980447': '{"video_latent_path": "video_latent/4980447.npy", "first_frame_latent_path": "first_frame_latent/4980447.npy", "prompt": "friends talking in a bar"}\n',
#  '6496243': '{"video_latent_path": "video_latent/6496243.npy", "first_frame_latent_path": "first_frame_latent/6496243.npy", "prompt": "women bullying their professor"}\n',
#  '5532902': '{"video_latent_path": "video_latent/5532902.npy", "first_frame_latent_path": "first_frame_latent/5532902.npy", "prompt": "family looking at laptop"}\n',
#  '10503845': '{"video_latent_path": "video_latent/10503845.npy", "first_frame_latent_path": "first_frame_latent/10503845.npy", "prompt": "kids holding art letters"}\n',
#  '8685426': '{"video_latent_path": "video_latent/8685426.npy", "first_frame_latent_path": "first_frame_latent/8685426.npy", "prompt": "two women working together inside an office"}\n',
#  '9185689': '{"video_latent_path": "video_latent/9185689.npy", "first_frame_latent_path": "first_frame_latent/9185689.npy", "prompt": "washing lettuces with tap water"}\n',
#  '5700939': '{"video_latent_path": "video_latent/5700939.npy", "first_frame_latent_path": "first_frame_latent/5700939.npy", "prompt": "a doctor talking the patient"}\n',
#  '4333149': '{"video_latent_path": "video_latent/4333149.npy", "first_frame_latent_path": "first_frame_latent/4333149.npy", "prompt": "couple buying a car"}\n',
#  '12063381': '{"video_latent_path": "video_latent/12063381.npy", "first_frame_latent_path": "first_frame_latent/12063381.npy", "prompt": "a happy woman jumping using jumping rope"}\n',
#  '6006139': '{"video_latent_path": "video_latent/6006139.npy", "first_frame_latent_path": "first_frame_latent/6006139.npy", "prompt": "A group of workers push a large tree trunk on a wheeled platform in a dirt yard surrounded by low buildings."}\n',
#  '3046184': '{"video_latent_path": "video_latent/3046184.npy", "first_frame_latent_path": "first_frame_latent/3046184.npy", "prompt": "An out-of-focus city street with blurry pedestrians, street lights, and a car in the background."}\n',
#  '10783202': '{"video_latent_path": "video_latent/10783202.npy", "first_frame_latent_path": "first_frame_latent/10783202.npy", "prompt": "a boxer wearing a boxing gloves"}\n',
#  '6286159': '{"video_latent_path": "video_latent/6286159.npy", "first_frame_latent_path": "first_frame_latent/6286159.npy", "prompt": "A person in a striped swimsuit leans on a yellow inflatable ring in a pool with colorful floats nearby under the sunlight."}\n',
#  '19504843': '{"video_latent_path": "video_latent/19504843.npy", "first_frame_latent_path": "first_frame_latent/19504843.npy", "prompt": "small colorful circles on black background"}\n',
#  '12475632': '{"video_latent_path": "video_latent/12475632.npy", "first_frame_latent_path": "first_frame_latent/12475632.npy", "prompt": "footage of a small waterfalls in the forest"}\n',
#  '17771119': '{"video_latent_path": "video_latent/17771119.npy", "first_frame_latent_path": "first_frame_latent/17771119.npy", "prompt": "aerial footage of frozen lake"}\n',
#  '8530031': '{"video_latent_path": "video_latent/8530031.npy", "first_frame_latent_path": "first_frame_latent/8530031.npy", "prompt": "grass swaying in the wind"}\n',
#  '3555559': '{"video_latent_path": "video_latent/3555559.npy", "first_frame_latent_path": "first_frame_latent/3555559.npy", "prompt": "A person with curly hair stands in front of a headboard with elegant metal swirls, casting soft shadows on the wall."}\n',
#  '3636655': '{"video_latent_path": "video_latent/3636655.npy", "first_frame_latent_path": "first_frame_latent/3636655.npy", "prompt": "women holding hands while lying on bed"}\n',
#  '6967645': '{"video_latent_path": "video_latent/6967645.npy", "first_frame_latent_path": "first_frame_latent/6967645.npy", "prompt": "happy family walking out of house"}\n',
#  '5116398': '{"video_latent_path": "video_latent/5116398.npy", "first_frame_latent_path": "first_frame_latent/5116398.npy", "prompt": "A close-up image of a hand holding a smoking rolled joint with smoke drifting upwards, set against a dimly lit background."}\n',
#  '4571347': '{"video_latent_path": "video_latent/4571347.npy", "first_frame_latent_path": "first_frame_latent/4571347.npy", "prompt": "man sitting in the car"}\n',
#  '8100632': '{"video_latent_path": "video_latent/8100632.npy", "first_frame_latent_path": "first_frame_latent/8100632.npy", "prompt": "woman sitting on the couch reading a book"}\n',
#  '7784808': '{"video_latent_path": "video_latent/7784808.npy", "first_frame_latent_path": "first_frame_latent/7784808.npy", "prompt": "A person sits at a rustic wooden table, engrossed in a large, open book, in a dimly lit room with a colorful window casting a blue hue."}\n',
#  '9506077': '{"video_latent_path": "video_latent/9506077.npy", "first_frame_latent_path": "first_frame_latent/9506077.npy", "prompt": "landscape nature fashion sand"}\n',
#  '9535374': '{"video_latent_path": "video_latent/9535374.npy", "first_frame_latent_path": "first_frame_latent/9535374.npy", "prompt": "a person using a chainsaw to cut a wood log"}\n',
#  '17801810': '{"video_latent_path": "video_latent/17801810.npy", "first_frame_latent_path": "first_frame_latent/17801810.npy", "prompt": "a man and a woman exchanging a seashell and a starfish"}\n',
#  '5089891': '{"video_latent_path": "video_latent/5089891.npy", "first_frame_latent_path": "first_frame_latent/5089891.npy", "prompt": "view of sea at sunset"}\n',
#  '6180104': '{"video_latent_path": "video_latent/6180104.npy", "first_frame_latent_path": "first_frame_latent/6180104.npy", "prompt": "A close-up captures the detail of a light brown wavy hair and an ear, set against a blurred white background."}\n',
#  '17673702': '{"video_latent_path": "video_latent/17673702.npy", "first_frame_latent_path": "first_frame_latent/17673702.npy", "prompt": "an aerial footage of a landscape in switzerland"}\n',
#  '10117956': '{"video_latent_path": "video_latent/10117956.npy", "first_frame_latent_path": "first_frame_latent/10117956.npy", "prompt": "woman placing ornaments on christmas tree"}\n',
#  '13056345': '{"video_latent_path": "video_latent/13056345.npy", "first_frame_latent_path": "first_frame_latent/13056345.npy", "prompt": "A group of individuals engages in a meeting around a table with laptops, notebooks, and smartphones, set against the backdrop of a whiteboard in a bright office space."}\n',
#  '10549374': '{"video_latent_path": "video_latent/10549374.npy", "first_frame_latent_path": "first_frame_latent/10549374.npy", "prompt": "a band playing mariachi music for guests in a restaurant"}\n',
#  '5101013': '{"video_latent_path": "video_latent/5101013.npy", "first_frame_latent_path": "first_frame_latent/5101013.npy", "prompt": "Four individuals are seated around a table amidst a creative workspace, engaged in what appears to be a collaborative activity with papers and learning materials."}\n',
#  '4112539': '{"video_latent_path": "video_latent/4112539.npy", "first_frame_latent_path": "first_frame_latent/4112539.npy", "prompt": "man hands gesturing while in virtual meeting"}\n',
#  '13058595': '{"video_latent_path": "video_latent/13058595.npy", "first_frame_latent_path": "first_frame_latent/13058595.npy", "prompt": "A silhouette is captured against a dimly lit blue background, wearing a hoodie with arms slightly raised."}\n',
#  '5771815': '{"video_latent_path": "video_latent/5771815.npy", "first_frame_latent_path": "first_frame_latent/5771815.npy", "prompt": "sunset across a chapel"}\n',
#  '18466929': '{"video_latent_path": "video_latent/18466929.npy", "first_frame_latent_path": "first_frame_latent/18466929.npy", "prompt": "A person is pressing a flower-shaped cutter into a flour-dusted dough to make cookies, with a glass of juice and a buttered pan nearby."}\n',
#  '4878657': '{"video_latent_path": "video_latent/4878657.npy", "first_frame_latent_path": "first_frame_latent/4878657.npy", "prompt": "landscape nature forest aerial"}\n',
#  '3957704': '{"video_latent_path": "video_latent/3957704.npy", "first_frame_latent_path": "first_frame_latent/3957704.npy", "prompt": "close up of a burning paper"}\n',
#  '13956207': '{"video_latent_path": "video_latent/13956207.npy", "first_frame_latent_path": "first_frame_latent/13956207.npy", "prompt": "airplane flying under a blue sky"}\n',
#  '8543793': '{"video_latent_path": "video_latent/8543793.npy", "first_frame_latent_path": "first_frame_latent/8543793.npy", "prompt": "person making a painting in a canvas"}\n',
#  '7352716': '{"video_latent_path": "video_latent/7352716.npy", "first_frame_latent_path": "first_frame_latent/7352716.npy", "prompt": "a sea bird dives to catch its prey"}\n',
#  '16079442': '{"video_latent_path": "video_latent/16079442.npy", "first_frame_latent_path": "first_frame_latent/16079442.npy", "prompt": "man and woman in a workshop"}\n',
#  '7261382': '{"video_latent_path": "video_latent/7261382.npy", "first_frame_latent_path": "first_frame_latent/7261382.npy", "prompt": "A hand with painted nails holds a sign that reads \'Where customers matter\', against a red background."}\n',
#  '5704967': '{"video_latent_path": "video_latent/5704967.npy", "first_frame_latent_path": "first_frame_latent/5704967.npy", "prompt": "people outside griffith observatory"}\n',
#  '3723516': '{"video_latent_path": "video_latent/3723516.npy", "first_frame_latent_path": "first_frame_latent/3723516.npy", "prompt": "A group of formally dressed individuals stands in a room adorned with an American flag, suggesting a solemn or official gathering."}\n',
#  '855231': '{"video_latent_path": "video_latent/855231.npy", "first_frame_latent_path": "first_frame_latent/855231.npy", "prompt": "a woman looking at photos"}\n',
#  '8865757': '{"video_latent_path": "video_latent/8865757.npy", "first_frame_latent_path": "first_frame_latent/8865757.npy", "prompt": "The still water reflects the clouds above as boats dock near a modern bridge connecting two parts of a city."}\n',
#  '8996080': '{"video_latent_path": "video_latent/8996080.npy", "first_frame_latent_path": "first_frame_latent/8996080.npy", "prompt": "forest autumn fall colors autumn forest"}\n',
#  '9083291': '{"video_latent_path": "video_latent/9083291.npy", "first_frame_latent_path": "first_frame_latent/9083291.npy", "prompt": "beautiful footage of ealing london park"}\n',
#  '19145166': '{"video_latent_path": "video_latent/19145166.npy", "first_frame_latent_path": "first_frame_latent/19145166.npy", "prompt": "A blurry image of a soccer match at night with players in orange and purple jerseys, an official in blue, and a rolling ball on the grass."}\n',
#  '10051505': '{"video_latent_path": "video_latent/10051505.npy", "first_frame_latent_path": "first_frame_latent/10051505.npy", "prompt": "girl caressing her dog in lavender fields"}\n',
#  '6694040': '{"video_latent_path": "video_latent/6694040.npy", "first_frame_latent_path": "first_frame_latent/6694040.npy", "prompt": "drone view of bordeaux city at sunset"}\n',
#  '5067905': '{"video_latent_path": "video_latent/5067905.npy", "first_frame_latent_path": "first_frame_latent/5067905.npy", "prompt": "a person skillfully playing his drums"}\n',
#  '12454399': '{"video_latent_path": "video_latent/12454399.npy", "first_frame_latent_path": "first_frame_latent/12454399.npy", "prompt": "point of view of a person walking along a creepy hotel corridor"}\n',
#  '19228170': '{"video_latent_path": "video_latent/19228170.npy", "first_frame_latent_path": "first_frame_latent/19228170.npy", "prompt": "Four individuals stand against a backdrop of yellow lockers, one holding a book, another gesturing animatedly, while a third clutches a coffee cup, and the fourth has headphones around their neck."}\n',
#  '8165903': '{"video_latent_path": "video_latent/8165903.npy", "first_frame_latent_path": "first_frame_latent/8165903.npy", "prompt": "manicurist scrubbing the nails with nail file"}\n',
#  '18449083': '{"video_latent_path": "video_latent/18449083.npy", "first_frame_latent_path": "first_frame_latent/18449083.npy", "prompt": "person holding a manual"}\n',
#  '18490311': '{"video_latent_path": "video_latent/18490311.npy", "first_frame_latent_path": "first_frame_latent/18490311.npy", "prompt": "kelp floating in the sea"}\n',
#  '4611883': '{"video_latent_path": "video_latent/4611883.npy", "first_frame_latent_path": "first_frame_latent/4611883.npy", "prompt": "A plowed field in the foreground looks onto rows of grapevines and trees with a cloudy sky."}\n',
#  '9957670': '{"video_latent_path": "video_latent/9957670.npy", "first_frame_latent_path": "first_frame_latent/9957670.npy", "prompt": "young couple preparing for christmas"}\n',
#  '11911255': '{"video_latent_path": "video_latent/11911255.npy", "first_frame_latent_path": "first_frame_latent/11911255.npy", "prompt": "close up view of the ingredients for spaghetti"}\n',
#  '7594008': '{"video_latent_path": "video_latent/7594008.npy", "first_frame_latent_path": "first_frame_latent/7594008.npy", "prompt": "a happy woman holding a vinyl record"}\n',
#  '8462519': '{"video_latent_path": "video_latent/8462519.npy", "first_frame_latent_path": "first_frame_latent/8462519.npy", "prompt": "man wearing a headset writing"}\n',
#  '16699999': '{"video_latent_path": "video_latent/16699999.npy", "first_frame_latent_path": "first_frame_latent/16699999.npy", "prompt": "beautiful scenery of autumn mood forest"}\n',
#  '11663555': '{"video_latent_path": "video_latent/11663555.npy", "first_frame_latent_path": "first_frame_latent/11663555.npy", "prompt": "aerial footage of a beach and threes"}\n',
#  '14350218': '{"video_latent_path": "video_latent/14350218.npy", "first_frame_latent_path": "first_frame_latent/14350218.npy", "prompt": "Four people, casually dressed, enjoy a lively conversation, holding bottles, with clear blue sky as their backdrop."}\n',
#  '9721726': '{"video_latent_path": "video_latent/9721726.npy", "first_frame_latent_path": "first_frame_latent/9721726.npy", "prompt": "a person placing a lighted candle on a table"}\n',
#  '10037744': '{"video_latent_path": "video_latent/10037744.npy", "first_frame_latent_path": "first_frame_latent/10037744.npy", "prompt": "a woman drinking tea on a teacup sitting on the ground"}\n',
#  '5765541': '{"video_latent_path": "video_latent/5765541.npy", "first_frame_latent_path": "first_frame_latent/5765541.npy", "prompt": "elderly man sitting looking at camera"}\n',
#  '8835830': '{"video_latent_path": "video_latent/8835830.npy", "first_frame_latent_path": "first_frame_latent/8835830.npy", "prompt": "time lapse video of cityscape during nighttime"}\n',
#  '7098269': '{"video_latent_path": "video_latent/7098269.npy", "first_frame_latent_path": "first_frame_latent/7098269.npy", "prompt": "woman doing sexy dance"}\n',
#  '2985407': '{"video_latent_path": "video_latent/2985407.npy", "first_frame_latent_path": "first_frame_latent/2985407.npy", "prompt": "a drone shot of a rocky coastline"}\n',
#  '6278709': '{"video_latent_path": "video_latent/6278709.npy", "first_frame_latent_path": "first_frame_latent/6278709.npy", "prompt": "little mouse in a box"}\n',
#  '13772821': '{"video_latent_path": "video_latent/13772821.npy", "first_frame_latent_path": "first_frame_latent/13772821.npy", "prompt": "man walking on the beach"}\n',
#  '2047892': '{"video_latent_path": "video_latent/2047892.npy", "first_frame_latent_path": "first_frame_latent/2047892.npy", "prompt": "Two individuals are embracing warmly against a backdrop of autumnal trees lit by soft sunlight."}\n',
#  '4360578': '{"video_latent_path": "video_latent/4360578.npy", "first_frame_latent_path": "first_frame_latent/4360578.npy", "prompt": "house with solar panels drone shot"}\n',
#  '12526001': '{"video_latent_path": "video_latent/12526001.npy", "first_frame_latent_path": "first_frame_latent/12526001.npy", "prompt": "women posting paper graphs on a corkboard"}\n',
#  '17285697': '{"video_latent_path": "video_latent/17285697.npy", "first_frame_latent_path": "first_frame_latent/17285697.npy", "prompt": "a mockup of stationery and a wooden hand"}\n',
#  '852335': '{"video_latent_path": "video_latent/852335.npy", "first_frame_latent_path": "first_frame_latent/852335.npy", "prompt": "a female figure skater in a red costume"}\n',
#  '6245835': '{"video_latent_path": "video_latent/6245835.npy", "first_frame_latent_path": "first_frame_latent/6245835.npy", "prompt": "video of a mountains with snow"}\n',
#  '7603361': '{"video_latent_path": "video_latent/7603361.npy", "first_frame_latent_path": "first_frame_latent/7603361.npy", "prompt": "drone footage of a coastal village"}\n',
#  '17672488': '{"video_latent_path": "video_latent/17672488.npy", "first_frame_latent_path": "first_frame_latent/17672488.npy", "prompt": "A bowl with colorful floral designs sits on a matching plate, with a blurred vase and stack of books in the background."}\n',
#  '5727534': '{"video_latent_path": "video_latent/5727534.npy", "first_frame_latent_path": "first_frame_latent/5727534.npy", "prompt": "man with prosthetic leg stretching in the beach"}\n',
#  '9957671': '{"video_latent_path": "video_latent/9957671.npy", "first_frame_latent_path": "first_frame_latent/9957671.npy", "prompt": "a man looking at his delivered foods"}\n',
#  '8462481': '{"video_latent_path": "video_latent/8462481.npy", "first_frame_latent_path": "first_frame_latent/8462481.npy", "prompt": "two dogs running in the woods"}\n',
#  '9198579': '{"video_latent_path": "video_latent/9198579.npy", "first_frame_latent_path": "first_frame_latent/9198579.npy", "prompt": "a wooden bench built on a tree"}\n',
#  '9302763': '{"video_latent_path": "video_latent/9302763.npy", "first_frame_latent_path": "first_frame_latent/9302763.npy", "prompt": "The sun sets behind a forested hill, casting a warm glow over the trees as the sky fades to dusk."}\n',
#  '19229631': '{"video_latent_path": "video_latent/19229631.npy", "first_frame_latent_path": "first_frame_latent/19229631.npy", "prompt": "boy sprays water to his friend"}\n',
#  '2965586': '{"video_latent_path": "video_latent/2965586.npy", "first_frame_latent_path": "first_frame_latent/2965586.npy", "prompt": "A person with green hair is captured in a side profile against a gradient dark background, still and introspective."}\n',
#  '7280341': '{"video_latent_path": "video_latent/7280341.npy", "first_frame_latent_path": "first_frame_latent/7280341.npy", "prompt": "an elderly man tying a string on a label"}\n',
#  '6731830': '{"video_latent_path": "video_latent/6731830.npy", "first_frame_latent_path": "first_frame_latent/6731830.npy", "prompt": "person slicing christmas cake"}\n',
#  '7313178': '{"video_latent_path": "video_latent/7313178.npy", "first_frame_latent_path": "first_frame_latent/7313178.npy", "prompt": "grandmother and granddaughter spending time together"}\n',
#  '18817527': '{"video_latent_path": "video_latent/18817527.npy", "first_frame_latent_path": "first_frame_latent/18817527.npy", "prompt": "woman putting a bandana on a man"}\n',
#  '5555470': '{"video_latent_path": "video_latent/5555470.npy", "first_frame_latent_path": "first_frame_latent/5555470.npy", "prompt": "aerial footage of winter forest"}\n',
#  '4076102': '{"video_latent_path": "video_latent/4076102.npy", "first_frame_latent_path": "first_frame_latent/4076102.npy", "prompt": "blooming cherry blossom flowers"}\n',
#  '5667410': '{"video_latent_path": "video_latent/5667410.npy", "first_frame_latent_path": "first_frame_latent/5667410.npy", "prompt": "a person tying shoelace"}\n',
#  '2850757': '{"video_latent_path": "video_latent/2850757.npy", "first_frame_latent_path": "first_frame_latent/2850757.npy", "prompt": "drone footage of the bosphorus bridge"}\n',
#  '3944840': '{"video_latent_path": "video_latent/3944840.npy", "first_frame_latent_path": "first_frame_latent/3944840.npy", "prompt": "A group of people gather on the ledge of an ancient stone aqueduct bridge, reflected in the calm water below."}\n',
#  '4804762': '{"video_latent_path": "video_latent/4804762.npy", "first_frame_latent_path": "first_frame_latent/4804762.npy", "prompt": "an elegant woman posing with flowers"}\n',
#  '7987563': '{"video_latent_path": "video_latent/7987563.npy", "first_frame_latent_path": "first_frame_latent/7987563.npy", "prompt": "bird s eye view of sunset"}\n',
#  '6389575': '{"video_latent_path": "video_latent/6389575.npy", "first_frame_latent_path": "first_frame_latent/6389575.npy", "prompt": "drone footage of a road in a forest area"}\n',
#  '5060174': '{"video_latent_path": "video_latent/5060174.npy", "first_frame_latent_path": "first_frame_latent/5060174.npy", "prompt": "a person making a sentence using letter tiles"}\n',
#  '6321877': '{"video_latent_path": "video_latent/6321877.npy", "first_frame_latent_path": "first_frame_latent/6321877.npy", "prompt": "hands caressing one another"}\n',
#  '6964709': '{"video_latent_path": "video_latent/6964709.npy", "first_frame_latent_path": "first_frame_latent/6964709.npy", "prompt": "a goalie standing near the hockey goal"}\n',
#  '1191537': '{"video_latent_path": "video_latent/1191537.npy", "first_frame_latent_path": "first_frame_latent/1191537.npy", "prompt": "rock formation on hill"}\n',
#  '3991960': '{"video_latent_path": "video_latent/3991960.npy", "first_frame_latent_path": "first_frame_latent/3991960.npy", "prompt": "men riding on skateboards on u turn"}\n',
#  '18549848': '{"video_latent_path": "video_latent/18549848.npy", "first_frame_latent_path": "first_frame_latent/18549848.npy", "prompt": "scouts looking at ducks"}\n',
#  '17526709': '{"video_latent_path": "video_latent/17526709.npy", "first_frame_latent_path": "first_frame_latent/17526709.npy", "prompt": "elderly people harvesting the lettuce"}\n',
#  '8293512': '{"video_latent_path": "video_latent/8293512.npy", "first_frame_latent_path": "first_frame_latent/8293512.npy", "prompt": "scientists working in the laboratory"}\n',
#  '6464623': '{"video_latent_path": "video_latent/6464623.npy", "first_frame_latent_path": "first_frame_latent/6464623.npy", "prompt": "woman rubbing her hands"}\n',
#  '6583820': '{"video_latent_path": "video_latent/6583820.npy", "first_frame_latent_path": "first_frame_latent/6583820.npy", "prompt": "a woman pouring a colored liquid from a test tube into a big beaker"}\n',
#  '5259877': '{"video_latent_path": "video_latent/5259877.npy", "first_frame_latent_path": "first_frame_latent/5259877.npy", "prompt": "clouds formation in the sky in a time lapse video"}\n',
#  '4560737': '{"video_latent_path": "video_latent/4560737.npy", "first_frame_latent_path": "first_frame_latent/4560737.npy", "prompt": "a woman using a laptop at a veranda on a sunny day"}\n',
#  '9276268': '{"video_latent_path": "video_latent/9276268.npy", "first_frame_latent_path": "first_frame_latent/9276268.npy", "prompt": "berries floating on a water"}\n',
#  '6890308': '{"video_latent_path": "video_latent/6890308.npy", "first_frame_latent_path": "first_frame_latent/6890308.npy", "prompt": "aerial footage of the mountains"}\n',
#  '3181040': '{"video_latent_path": "video_latent/3181040.npy", "first_frame_latent_path": "first_frame_latent/3181040.npy", "prompt": "A towering golden Buddha statue overlooks a lush green landscape dotted with red-roofed buildings and winding roads."}\n',
#  '5906016': '{"video_latent_path": "video_latent/5906016.npy", "first_frame_latent_path": "first_frame_latent/5906016.npy", "prompt": "person holding a tall grass leaf"}\n',
#  '857159': '{"video_latent_path": "video_latent/857159.npy", "first_frame_latent_path": "first_frame_latent/857159.npy", "prompt": "A man dances and twirls a flaming object, creating a shower of sparks over the water at night."}\n',
#  '6510821': '{"video_latent_path": "video_latent/6510821.npy", "first_frame_latent_path": "first_frame_latent/6510821.npy", "prompt": "video of a hot air balloon and sea"}\n',
#  '4496294': '{"video_latent_path": "video_latent/4496294.npy", "first_frame_latent_path": "first_frame_latent/4496294.npy", "prompt": "women talking in the pool"}\n',
#  '6743541': '{"video_latent_path": "video_latent/6743541.npy", "first_frame_latent_path": "first_frame_latent/6743541.npy", "prompt": "bullying a classmate inside the classroom"}\n',
#  '7154942': '{"video_latent_path": "video_latent/7154942.npy", "first_frame_latent_path": "first_frame_latent/7154942.npy", "prompt": "aerial footage of green mountains"}\n',
#  '3116764': '{"video_latent_path": "video_latent/3116764.npy", "first_frame_latent_path": "first_frame_latent/3116764.npy", "prompt": "A person\'s hands are using a knife and fork to cut into a folded tortilla filled with meat on a colorful, patterned tablecloth."}\n',
#  '11685778': '{"video_latent_path": "video_latent/11685778.npy", "first_frame_latent_path": "first_frame_latent/11685778.npy", "prompt": "reeds near the river"}\n',
#  '6201173': '{"video_latent_path": "video_latent/6201173.npy", "first_frame_latent_path": "first_frame_latent/6201173.npy", "prompt": "top view footage road with vehicle passing by"}\n',
#  '1128321': '{"video_latent_path": "video_latent/1128321.npy", "first_frame_latent_path": "first_frame_latent/1128321.npy", "prompt": "close up on feeding cow"}\n',
#  '9869601': '{"video_latent_path": "video_latent/9869601.npy", "first_frame_latent_path": "first_frame_latent/9869601.npy", "prompt": "drone footage of downtown los angeles"}\n',
#  '11557946': '{"video_latent_path": "video_latent/11557946.npy", "first_frame_latent_path": "first_frame_latent/11557946.npy", "prompt": "an aerial footage of a red sky"}\n',
#  '17757994': '{"video_latent_path": "video_latent/17757994.npy", "first_frame_latent_path": "first_frame_latent/17757994.npy", "prompt": "A river flows through a cityscape with boats and people walking along the bank, while majestic domed buildings stand in the background."}\n',
#  '4410492': '{"video_latent_path": "video_latent/4410492.npy", "first_frame_latent_path": "first_frame_latent/4410492.npy", "prompt": "a man walking barefooted in the desert sand"}\n',
#  '15039469': '{"video_latent_path": "video_latent/15039469.npy", "first_frame_latent_path": "first_frame_latent/15039469.npy", "prompt": "woman putting on wall climbing gears"}\n',
#  '10186934': '{"video_latent_path": "video_latent/10186934.npy", "first_frame_latent_path": "first_frame_latent/10186934.npy", "prompt": "woman pointing a gun to a man in a futuristic room"}\n',
#  '6650234': '{"video_latent_path": "video_latent/6650234.npy", "first_frame_latent_path": "first_frame_latent/6650234.npy", "prompt": "a woman in orange suit talking on her cellphone"}\n',
#  '10000366': '{"video_latent_path": "video_latent/10000366.npy", "first_frame_latent_path": "first_frame_latent/10000366.npy", "prompt": "group of friends having a toast"}\n',
#  '17231896': '{"video_latent_path": "video_latent/17231896.npy", "first_frame_latent_path": "first_frame_latent/17231896.npy", "prompt": "a woman cutting a piece from a spread of fabric"}\n',
#  '10458146': '{"video_latent_path": "video_latent/10458146.npy", "first_frame_latent_path": "first_frame_latent/10458146.npy", "prompt": "shot of a wild burrowing owl athene cunicularia"}\n',
#  '13573912': '{"video_latent_path": "video_latent/13573912.npy", "first_frame_latent_path": "first_frame_latent/13573912.npy", "prompt": "blank business cards on white ceramic plate"}\n',
#  '5478374': '{"video_latent_path": "video_latent/5478374.npy", "first_frame_latent_path": "first_frame_latent/5478374.npy", "prompt": "Two individuals stand by a calm waterside, with reeds in the background, one facing away in contemplation and the other glancing sideways."}\n',
#  '8087070': '{"video_latent_path": "video_latent/8087070.npy", "first_frame_latent_path": "first_frame_latent/8087070.npy", "prompt": "Two individuals sit closely on the beach, sharing a candid moment with cans in their hands amidst a backdrop of driftwood and serene shores."}\n',
#  '7535100': '{"video_latent_path": "video_latent/7535100.npy", "first_frame_latent_path": "first_frame_latent/7535100.npy", "prompt": "drone footage of a desert"}\n',
#  '7408003': '{"video_latent_path": "video_latent/7408003.npy", "first_frame_latent_path": "first_frame_latent/7408003.npy", "prompt": "flowers blowing in the wind"}\n',
#  '14388161': '{"video_latent_path": "video_latent/14388161.npy", "first_frame_latent_path": "first_frame_latent/14388161.npy", "prompt": "beach and sand dunes at sunset"}\n',
#  '8614005': '{"video_latent_path": "video_latent/8614005.npy", "first_frame_latent_path": "first_frame_latent/8614005.npy", "prompt": "a man walking in a forest"}\n',
#  '7174283': '{"video_latent_path": "video_latent/7174283.npy", "first_frame_latent_path": "first_frame_latent/7174283.npy", "prompt": "A person is seated in an armchair playing the flute, with a laptop on a table and a potted plant nearby."}\n',
#  '4584765': '{"video_latent_path": "video_latent/4584765.npy", "first_frame_latent_path": "first_frame_latent/4584765.npy", "prompt": "a man walking a the side of an abandoned factory"}\n',
#  '6952088': '{"video_latent_path": "video_latent/6952088.npy", "first_frame_latent_path": "first_frame_latent/6952088.npy", "prompt": "kids playing with a water hose"}\n',
#  '7117532': '{"video_latent_path": "video_latent/7117532.npy", "first_frame_latent_path": "first_frame_latent/7117532.npy", "prompt": "aerial view of a coastal city"}\n',
#  '8691032': '{"video_latent_path": "video_latent/8691032.npy", "first_frame_latent_path": "first_frame_latent/8691032.npy", "prompt": "man using calculator at the office"}\n',
#  '6755010': '{"video_latent_path": "video_latent/6755010.npy", "first_frame_latent_path": "first_frame_latent/6755010.npy", "prompt": "low angle shot of female engineer wiping her sweat away"}\n',
#  '7774349': '{"video_latent_path": "video_latent/7774349.npy", "first_frame_latent_path": "first_frame_latent/7774349.npy", "prompt": "A man with a bandaged arm stands in a gymnasium, with a woman in a pink shirt reaching towards him."}\n',
#  '6974582': '{"video_latent_path": "video_latent/6974582.npy", "first_frame_latent_path": "first_frame_latent/6974582.npy", "prompt": "a woman wearing an eyeglass while working"}\n',
#  '8762776': '{"video_latent_path": "video_latent/8762776.npy", "first_frame_latent_path": "first_frame_latent/8762776.npy", "prompt": "The aerial view shows people lounging on a sandy beach with colorful umbrellas, while others play in the shallow green waters."}\n',
#  '9209847': '{"video_latent_path": "video_latent/9209847.npy", "first_frame_latent_path": "first_frame_latent/9209847.npy", "prompt": "a person making coffee"}\n',
#  '4498417': '{"video_latent_path": "video_latent/4498417.npy", "first_frame_latent_path": "first_frame_latent/4498417.npy", "prompt": "Two individuals wearing colorful beanies and jackets stand by a purple column in an underground parking garage."}\n',
#  '7986196': '{"video_latent_path": "video_latent/7986196.npy", "first_frame_latent_path": "first_frame_latent/7986196.npy", "prompt": "girl on slide in playground"}\n',
#  '5251985': '{"video_latent_path": "video_latent/5251985.npy", "first_frame_latent_path": "first_frame_latent/5251985.npy", "prompt": "black sports car on country road"}\n',
#  '8308977': '{"video_latent_path": "video_latent/8308977.npy", "first_frame_latent_path": "first_frame_latent/8308977.npy", "prompt": "a woman writing on her notebook while drinking wine"}\n',
#  '17505027': '{"video_latent_path": "video_latent/17505027.npy", "first_frame_latent_path": "first_frame_latent/17505027.npy", "prompt": "elderly man working out"}\n',
#  '6765287': '{"video_latent_path": "video_latent/6765287.npy", "first_frame_latent_path": "first_frame_latent/6765287.npy", "prompt": "An individual sits at a desk illuminated by a desk lamp in a dimly lit room with tall windows showing evening light outside."}\n',
#  '5809670': '{"video_latent_path": "video_latent/5809670.npy", "first_frame_latent_path": "first_frame_latent/5809670.npy", "prompt": "A vibrantly green grasshopper stands still on the sandy ground scattered with tiny rocks, illuminated by the warm sunlight."}\n',
#  '7429433': '{"video_latent_path": "video_latent/7429433.npy", "first_frame_latent_path": "first_frame_latent/7429433.npy", "prompt": "mother and daughter walking a dog"}\n',
#  '13575202': '{"video_latent_path": "video_latent/13575202.npy", "first_frame_latent_path": "first_frame_latent/13575202.npy", "prompt": "a mother putting white roses on her daughter s hair"}\n',
#  '12886082': '{"video_latent_path": "video_latent/12886082.npy", "first_frame_latent_path": "first_frame_latent/12886082.npy", "prompt": "a boxer wearing a mouthguard"}\n',
#  '5765449': '{"video_latent_path": "video_latent/5765449.npy", "first_frame_latent_path": "first_frame_latent/5765449.npy", "prompt": "man climbing on artificial rocks"}\n',
#  '6740730': '{"video_latent_path": "video_latent/6740730.npy", "first_frame_latent_path": "first_frame_latent/6740730.npy", "prompt": "A chandelier hangs from a high ceiling, its lightbulbs casting a warm glow on the ornate patterns and stained glass windows."}\n',
#  '8582847': '{"video_latent_path": "video_latent/8582847.npy", "first_frame_latent_path": "first_frame_latent/8582847.npy", "prompt": "A person in a red shirt is using a cellphone while another person in a reddish-purplish shirt is using a cloth to dry their hands."}\n',
#  '7593564': '{"video_latent_path": "video_latent/7593564.npy", "first_frame_latent_path": "first_frame_latent/7593564.npy", "prompt": "Vehicles navigate a winding road surrounded by rocky cliffs and dried grass under a hazy sky."}\n',
#  '12907193': '{"video_latent_path": "video_latent/12907193.npy", "first_frame_latent_path": "first_frame_latent/12907193.npy", "prompt": "a group of active elderly people having a fun conversation"}\n',
#  '854127': '{"video_latent_path": "video_latent/854127.npy", "first_frame_latent_path": "first_frame_latent/854127.npy", "prompt": "models sitting on the chair while in the shore"}\n',
#  '6961629': '{"video_latent_path": "video_latent/6961629.npy", "first_frame_latent_path": "first_frame_latent/6961629.npy", "prompt": "A person in a suit is pointing at a laptop screen displaying graphs, likely discussing business metrics in a modern office setting."}\n',
#  '12897186': '{"video_latent_path": "video_latent/12897186.npy", "first_frame_latent_path": "first_frame_latent/12897186.npy", "prompt": "elderly man using a tablet while sitting on the sofa"}\n',
#  '12737498': '{"video_latent_path": "video_latent/12737498.npy", "first_frame_latent_path": "first_frame_latent/12737498.npy", "prompt": "a young lady walking among plants in a greenhouse"}\n',
#  '4265084': '{"video_latent_path": "video_latent/4265084.npy", "first_frame_latent_path": "first_frame_latent/4265084.npy", "prompt": "a close up video of a beautiful woman"}\n',
#  '3405806': '{"video_latent_path": "video_latent/3405806.npy", "first_frame_latent_path": "first_frame_latent/3405806.npy", "prompt": "view of a seascape under blue sky"}\n',
#  '5839032': '{"video_latent_path": "video_latent/5839032.npy", "first_frame_latent_path": "first_frame_latent/5839032.npy", "prompt": "colorful hot air balloons in the sky"}\n',
#  '8899611': '{"video_latent_path": "video_latent/8899611.npy", "first_frame_latent_path": "first_frame_latent/8899611.npy", "prompt": "illuminated buildings in city"}\n',
#  '6942888': '{"video_latent_path": "video_latent/6942888.npy", "first_frame_latent_path": "first_frame_latent/6942888.npy", "prompt": "rear view on man and woman walking on grass"}\n',
#  '7182019': '{"video_latent_path": "video_latent/7182019.npy", "first_frame_latent_path": "first_frame_latent/7182019.npy", "prompt": "A person in a red sweater leans over a pool table, cue in hand, preparing to strike the white ball."}\n',
#  '1793156': '{"video_latent_path": "video_latent/1793156.npy", "first_frame_latent_path": "first_frame_latent/1793156.npy", "prompt": "drone footage of ocean"}\n',
#  '5708632': '{"video_latent_path": "video_latent/5708632.npy", "first_frame_latent_path": "first_frame_latent/5708632.npy", "prompt": "kids busy playing with wooden toys in a playroom"}\n',
#  '6286885': '{"video_latent_path": "video_latent/6286885.npy", "first_frame_latent_path": "first_frame_latent/6286885.npy", "prompt": "A person in a red floral shirt stands with a guitar on a grassy hill overlooking a misty mountainous landscape."}\n',
#  '5375690': '{"video_latent_path": "video_latent/5375690.npy", "first_frame_latent_path": "first_frame_latent/5375690.npy", "prompt": "drone view of modern city"}\n',
#  '8122594': '{"video_latent_path": "video_latent/8122594.npy", "first_frame_latent_path": "first_frame_latent/8122594.npy", "prompt": "top view footage of a small river in the forest"}\n',
#  '17788954': '{"video_latent_path": "video_latent/17788954.npy", "first_frame_latent_path": "first_frame_latent/17788954.npy", "prompt": "wood sea landscape beach"}\n',
#  '3622214': '{"video_latent_path": "video_latent/3622214.npy", "first_frame_latent_path": "first_frame_latent/3622214.npy", "prompt": "boy playing chess looking at the camera"}\n',
# ...
#  '8293010': '{"video_latent_path": "video_latent/8293010.npy", "first_frame_latent_path": "first_frame_latent/8293010.npy", "prompt": "a person cutting chives on a chopping board"}\n',
#  '6831477': '{"video_latent_path": "video_latent/6831477.npy", "first_frame_latent_path": "first_frame_latent/6831477.npy", "prompt": "A hiker stands atop a grassy hill, gazing out over a vast expanse of rolling, forest-covered mountains stretching towards the horizon under a partly cloudy sky."}\n',
#  '10217963': '{"video_latent_path": "video_latent/10217963.npy", "first_frame_latent_path": "first_frame_latent/10217963.npy", "prompt": "man and a woman with baby lying down under a blanket"}\n',
#  '4915299': '{"video_latent_path": "video_latent/4915299.npy", "first_frame_latent_path": "first_frame_latent/4915299.npy", "prompt": "a drone footage of people warming up near the cliff"}\n',
#  '3727026': '{"video_latent_path": "video_latent/3727026.npy", "first_frame_latent_path": "first_frame_latent/3727026.npy", "prompt": "A person in a patterned shirt stands behind a black podium, gesturing with their hands in mid-motion, against a plain backdrop."}\n',
#  '10397165': '{"video_latent_path": "video_latent/10397165.npy", "first_frame_latent_path": "first_frame_latent/10397165.npy", "prompt": "splashing water from the waves"}\n',
#  '9807230': '{"video_latent_path": "video_latent/9807230.npy", "first_frame_latent_path": "first_frame_latent/9807230.npy", "prompt": "a gypsy woman dancing while a man plays music in a field"}\n',
#  '4039194': '{"video_latent_path": "video_latent/4039194.npy", "first_frame_latent_path": "first_frame_latent/4039194.npy", "prompt": "water flowing in a rocky river"}\n',
#  '8047353': '{"video_latent_path": "video_latent/8047353.npy", "first_frame_latent_path": "first_frame_latent/8047353.npy", "prompt": "clear sky over mountains"}\n',
#  '6038861': '{"video_latent_path": "video_latent/6038861.npy", "first_frame_latent_path": "first_frame_latent/6038861.npy", "prompt": "waves and beach umbrellas on beach"}\n',
#  '6610239': '{"video_latent_path": "video_latent/6610239.npy", "first_frame_latent_path": "first_frame_latent/6610239.npy", "prompt": "A blue and white tugboat with the name \'KTK BARAKUDA\' floats on a calm sea, making gentle ripples in the water."}\n',
#  '7156549': '{"video_latent_path": "video_latent/7156549.npy", "first_frame_latent_path": "first_frame_latent/7156549.npy", "prompt": "young muslim woman posing looking at camera"}\n',
#  '9365454': '{"video_latent_path": "video_latent/9365454.npy", "first_frame_latent_path": "first_frame_latent/9365454.npy", "prompt": "Two Girl Scouts, clad in their uniforms and neckerchiefs, stand in a sunlit field holding boxes of Girl Scout cookies, with the sun peeking through the trees behind them."}\n',
#  '10264386': '{"video_latent_path": "video_latent/10264386.npy", "first_frame_latent_path": "first_frame_latent/10264386.npy", "prompt": "drone footage of lake and hills"}\n',
#  '9317428': '{"video_latent_path": "video_latent/9317428.npy", "first_frame_latent_path": "first_frame_latent/9317428.npy", "prompt": "a person standing in the middle of ocean"}\n',
#  '5542012': '{"video_latent_path": "video_latent/5542012.npy", "first_frame_latent_path": "first_frame_latent/5542012.npy", "prompt": "happy woman raising toast at a family dinner"}\n',
#  '3006846': '{"video_latent_path": "video_latent/3006846.npy", "first_frame_latent_path": "first_frame_latent/3006846.npy", "prompt": "drone footage of train passing by"}\n',
#  '7829859': '{"video_latent_path": "video_latent/7829859.npy", "first_frame_latent_path": "first_frame_latent/7829859.npy", "prompt": "An artist sitting on a stool starts painting colorful circles on a canvas, referencing a vibrant picture beside her."}\n',
#  '6077078': '{"video_latent_path": "video_latent/6077078.npy", "first_frame_latent_path": "first_frame_latent/6077078.npy", "prompt": "man playing a music then dancing with a woman"}\n',
#  '6132800': '{"video_latent_path": "video_latent/6132800.npy", "first_frame_latent_path": "first_frame_latent/6132800.npy", "prompt": "hyperlapse of city suburbs"}\n',
#  '4896221': '{"video_latent_path": "video_latent/4896221.npy", "first_frame_latent_path": "first_frame_latent/4896221.npy", "prompt": "aerial footage of waves crashing on shore"}\n',
#  '5102617': '{"video_latent_path": "video_latent/5102617.npy", "first_frame_latent_path": "first_frame_latent/5102617.npy", "prompt": "a man putting clothes inside a washing machine"}\n',
#  '14621244': '{"video_latent_path": "video_latent/14621244.npy", "first_frame_latent_path": "first_frame_latent/14621244.npy", "prompt": "video of a man meditating"}\n',
#  '6930827': '{"video_latent_path": "video_latent/6930827.npy", "first_frame_latent_path": "first_frame_latent/6930827.npy", "prompt": "woman painting while standing"}\n',
#  '15556048': '{"video_latent_path": "video_latent/15556048.npy", "first_frame_latent_path": "first_frame_latent/15556048.npy", "prompt": "close up on asian food on pan"}\n',
#  '15170714': '{"video_latent_path": "video_latent/15170714.npy", "first_frame_latent_path": "first_frame_latent/15170714.npy", "prompt": "close up view of a person talking"}\n',
#  '7123350': '{"video_latent_path": "video_latent/7123350.npy", "first_frame_latent_path": "first_frame_latent/7123350.npy", "prompt": "soil with earthworms"}\n',
#  '13542278': '{"video_latent_path": "video_latent/13542278.npy", "first_frame_latent_path": "first_frame_latent/13542278.npy", "prompt": "a young woman with mirror balls"}\n',
#  '10038888': '{"video_latent_path": "video_latent/10038888.npy", "first_frame_latent_path": "first_frame_latent/10038888.npy", "prompt": "back view footage of people shooting balls in a a ring of an arcade machine"}\n',
#  '5697818': '{"video_latent_path": "video_latent/5697818.npy", "first_frame_latent_path": "first_frame_latent/5697818.npy", "prompt": "a woman smelling the bottle"}\n',
#  '4122171': '{"video_latent_path": "video_latent/4122171.npy", "first_frame_latent_path": "first_frame_latent/4122171.npy", "prompt": "A group of people, inside a gymnasium, join hands in unity, possibly signaling teamwork or the beginning of a collaborative activity."}\n',
#  '10709520': '{"video_latent_path": "video_latent/10709520.npy", "first_frame_latent_path": "first_frame_latent/10709520.npy", "prompt": "close up of water drops falling on a tomato"}\n',
#  '4820927': '{"video_latent_path": "video_latent/4820927.npy", "first_frame_latent_path": "first_frame_latent/4820927.npy", "prompt": "A person in a wetsuit stands beside vibrant beach huts, holding a longboard, ready to hit the waves."}\n',
#  '14927776': '{"video_latent_path": "video_latent/14927776.npy", "first_frame_latent_path": "first_frame_latent/14927776.npy", "prompt": "A pile of pink medical face masks on a blue background, laying still with no movement."}\n',
#  '4360154': '{"video_latent_path": "video_latent/4360154.npy", "first_frame_latent_path": "first_frame_latent/4360154.npy", "prompt": "couple checking their bills"}\n',
#  '7507666': '{"video_latent_path": "video_latent/7507666.npy", "first_frame_latent_path": "first_frame_latent/7507666.npy", "prompt": "man tracing a leather piece"}\n',
#  '5099919': '{"video_latent_path": "video_latent/5099919.npy", "first_frame_latent_path": "first_frame_latent/5099919.npy", "prompt": "A tranquil scene of a lighthouse standing at the end of a rocky pier, surrounded by the calm blue sea."}\n',
#  '6376812': '{"video_latent_path": "video_latent/6376812.npy", "first_frame_latent_path": "first_frame_latent/6376812.npy", "prompt": "flowers plants lady beautiful"}\n',
#  '6503021': '{"video_latent_path": "video_latent/6503021.npy", "first_frame_latent_path": "first_frame_latent/6503021.npy", "prompt": "video of a woman looking at camera"}\n',
#  '7427945': '{"video_latent_path": "video_latent/7427945.npy", "first_frame_latent_path": "first_frame_latent/7427945.npy", "prompt": "Two individuals stand side by side against a sunlit backdrop, donning white attire, one with a sunflower tattoo visible on the chest."}\n',
#  '8979511': '{"video_latent_path": "video_latent/8979511.npy", "first_frame_latent_path": "first_frame_latent/8979511.npy", "prompt": "Dozens of flickering candles in red holders illuminate the dark space, creating a serene and reflective atmosphere."}\n',
#  '18332693': '{"video_latent_path": "video_latent/18332693.npy", "first_frame_latent_path": "first_frame_latent/18332693.npy", "prompt": "aerial footage of a road"}\n',
#  '7845522': '{"video_latent_path": "video_latent/7845522.npy", "first_frame_latent_path": "first_frame_latent/7845522.npy", "prompt": "close up of a blooming water lily on a water"}\n',
#  '6785559': '{"video_latent_path": "video_latent/6785559.npy", "first_frame_latent_path": "first_frame_latent/6785559.npy", "prompt": "A family is gathered around a dinner table adorned with candles, sharing a meal in a cozy, dimly-lit room."}\n',
#  '5900168': '{"video_latent_path": "video_latent/5900168.npy", "first_frame_latent_path": "first_frame_latent/5900168.npy", "prompt": "couple hugging looking at winter landscape"}\n',
#  '18567536': '{"video_latent_path": "video_latent/18567536.npy", "first_frame_latent_path": "first_frame_latent/18567536.npy", "prompt": "a woman with plastic on her face walking on a dirty shore"}\n',
#  '6517484': '{"video_latent_path": "video_latent/6517484.npy", "first_frame_latent_path": "first_frame_latent/6517484.npy", "prompt": "person using a turntable"}\n',
#  '7843402': '{"video_latent_path": "video_latent/7843402.npy", "first_frame_latent_path": "first_frame_latent/7843402.npy", "prompt": "man rolling flat a dough with rolling pin"}\n',
#  '8723035': '{"video_latent_path": "video_latent/8723035.npy", "first_frame_latent_path": "first_frame_latent/8723035.npy", "prompt": "person pouring sauce into burrito"}\n',
#  '8808481': '{"video_latent_path": "video_latent/8808481.npy", "first_frame_latent_path": "first_frame_latent/8808481.npy", "prompt": "A symmetrical image made up of fluid art in yellow and pink colors, with dynamic movements and shapes."}\n',
#  '10374277': '{"video_latent_path": "video_latent/10374277.npy", "first_frame_latent_path": "first_frame_latent/10374277.npy", "prompt": "Swirling green smoke creates an ethereal and mysterious atmosphere, moving and shifting in the darkness."}\n',
#  '3945140': '{"video_latent_path": "video_latent/3945140.npy", "first_frame_latent_path": "first_frame_latent/3945140.npy", "prompt": "Children in blue jerseys are playing soccer on a lush green field, casting long shadows in the bright sunlight."}\n',
#  '15812376': '{"video_latent_path": "video_latent/15812376.npy", "first_frame_latent_path": "first_frame_latent/15812376.npy", "prompt": "a woman looking out the car window"}\n',
#  '14017305': '{"video_latent_path": "video_latent/14017305.npy", "first_frame_latent_path": "first_frame_latent/14017305.npy", "prompt": "low angle view of turkish flags waving on top of a rocky mountain"}\n',
#  '13359556': '{"video_latent_path": "video_latent/13359556.npy", "first_frame_latent_path": "first_frame_latent/13359556.npy", "prompt": "The image captures a blurry background featuring structures, possibly indicating motion or a quick snapshot."}\n',
#  '6159869': '{"video_latent_path": "video_latent/6159869.npy", "first_frame_latent_path": "first_frame_latent/6159869.npy", "prompt": "a ski lift over snow covered mountains"}\n',
#  '8375699': '{"video_latent_path": "video_latent/8375699.npy", "first_frame_latent_path": "first_frame_latent/8375699.npy", "prompt": "woman with makeup posing on camera"}\n',
#  '3147100': '{"video_latent_path": "video_latent/3147100.npy", "first_frame_latent_path": "first_frame_latent/3147100.npy", "prompt": "women wearing face mask while working in front of a laptop"}\n',
#  '9108418': '{"video_latent_path": "video_latent/9108418.npy", "first_frame_latent_path": "first_frame_latent/9108418.npy", "prompt": "serving a draft beer"}\n',
#  '9095886': '{"video_latent_path": "video_latent/9095886.npy", "first_frame_latent_path": "first_frame_latent/9095886.npy", "prompt": "woman putting cosmetic product on her face"}\n',
#  '5395867': '{"video_latent_path": "video_latent/5395867.npy", "first_frame_latent_path": "first_frame_latent/5395867.npy", "prompt": "Tall, slender trees stand amidst a misty, green forest with gentle rain falling, creating a serene and peaceful atmosphere."}\n',
#  '7131827': '{"video_latent_path": "video_latent/7131827.npy", "first_frame_latent_path": "first_frame_latent/7131827.npy", "prompt": "a footage of a vending machine"}\n',
#  '7429371': '{"video_latent_path": "video_latent/7429371.npy", "first_frame_latent_path": "first_frame_latent/7429371.npy", "prompt": "A person in a green jacket is sitting on grass with graffiti on the wall behind, while another stands close by."}\n',
#  '9772313': '{"video_latent_path": "video_latent/9772313.npy", "first_frame_latent_path": "first_frame_latent/9772313.npy", "prompt": "couple walking on the sand"}\n',
#  '6582607': '{"video_latent_path": "video_latent/6582607.npy", "first_frame_latent_path": "first_frame_latent/6582607.npy", "prompt": "A person in colorful attire stands in a spacious room with a reflective glass wall, holding open a patterned jacket."}\n',
#  '9562220': '{"video_latent_path": "video_latent/9562220.npy", "first_frame_latent_path": "first_frame_latent/9562220.npy", "prompt": "a person putting a sticker on a paper bag"}\n',
#  '5974884': '{"video_latent_path": "video_latent/5974884.npy", "first_frame_latent_path": "first_frame_latent/5974884.npy", "prompt": "aerial footage of a mountain range"}\n',
#  '16029681': '{"video_latent_path": "video_latent/16029681.npy", "first_frame_latent_path": "first_frame_latent/16029681.npy", "prompt": "People walk along a street with colorful buses parked next to a building adorned with a large mural of a woman painting."}\n',
#  '8439977': '{"video_latent_path": "video_latent/8439977.npy", "first_frame_latent_path": "first_frame_latent/8439977.npy", "prompt": "decorating the table with cherries"}\n',
#  '5703059': '{"video_latent_path": "video_latent/5703059.npy", "first_frame_latent_path": "first_frame_latent/5703059.npy", "prompt": "A person in a white shirt gestures during a discussion at a table with documents, pens, and a tape dispenser, with others attentively listening."}\n',
#  '9831120': '{"video_latent_path": "video_latent/9831120.npy", "first_frame_latent_path": "first_frame_latent/9831120.npy", "prompt": "a man playing the drum set"}\n',
#  '3804349': '{"video_latent_path": "video_latent/3804349.npy", "first_frame_latent_path": "first_frame_latent/3804349.npy", "prompt": "A bustling city street flanked by modern apartment buildings, with cars stopped at a red light amidst the early evening glow."}\n',
#  '5266881': '{"video_latent_path": "video_latent/5266881.npy", "first_frame_latent_path": "first_frame_latent/5266881.npy", "prompt": "a man talking to an elderly couple"}\n',
#  '10416880': '{"video_latent_path": "video_latent/10416880.npy", "first_frame_latent_path": "first_frame_latent/10416880.npy", "prompt": "close up video of a person cutting the wood"}\n',
#  '19538588': '{"video_latent_path": "video_latent/19538588.npy", "first_frame_latent_path": "first_frame_latent/19538588.npy", "prompt": "ferry boats sailing in a river on a foggy morning"}\n',
#  '5137338': '{"video_latent_path": "video_latent/5137338.npy", "first_frame_latent_path": "first_frame_latent/5137338.npy", "prompt": "a couple bonding with their child in a kitchen"}\n',
#  '13859858': '{"video_latent_path": "video_latent/13859858.npy", "first_frame_latent_path": "first_frame_latent/13859858.npy", "prompt": "man lighting cigarette in a dark room"}\n',
#  '13285664': '{"video_latent_path": "video_latent/13285664.npy", "first_frame_latent_path": "first_frame_latent/13285664.npy", "prompt": "Two people, one in a white shirt and the other in a casual tee, are about to high-five with a vibrant yellow background."}\n'}
