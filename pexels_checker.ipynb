# %%
import os

# %%
tmp10klist = os.listdir('/mnt/carpedkm_data/image_gen_ds/second_stage_video_train_pexels_8fps_10k')

# %%
ids_str = ''
for tm in tmp10klist:
    id_ = tm.split('_')[0]
    ids_str += f'{id_}\n'

# %%
ids_str
# Out:
# '10001946\n10002045\n10013626\n10021299\n10021327\n10025427\n10027100\n10028146\n10030527\n10031937\n10032755\n10033149\n10034020\n10037745\n10038815\n1003928\n10040223\n10041353\n10041562\n10041597\n10042793\n10042891\n10042933\n10042942\n10043052\n10048555\n10049401\n10050162\n10050972\n10059768\n10061594\n10063280\n10065283\n10068007\n10069585\n10070434\n10070946\n10072115\n10082779\n10083061\n10085051\n10095265\n10101930\n10103782\n10106039\n10106711\n10117746\n10117749\n10117926\n10119136\n10119533\n10120130\n10123290\n10124138\n10132257\n10132369\n10132620\n10133899\n10139119\n10139264\n10139699\n10139705\n10141040\n10143251\n10149360\n10150311\n10152752\n10155076\n10155783\n10159367\n10159469\n10159491\n10159499\n10166641\n10171434\n10177963\n10179222\n10179447\n10179453\n10180994\n10182491\n10187858\n10187913\n10189444\n10189831\n10202756\n10202757\n10202761\n10202812\n10202887\n10203246\n10203948\n10209167\n10211607\n10218133\n10220168\n10220215\n10222340\n10222958\n10224139
# ...

# %%
with open('./pexels_10k_ids.txt', 'w') as f:
    f.write(ids_str)
