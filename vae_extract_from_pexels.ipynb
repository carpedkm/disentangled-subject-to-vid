# %%
import os
from tqdm import tqdm

# %%
path = '/mnt/video_data/pexels/metadata/results_400k_train_rfcap_pexels_reformat_clean.csv'

# %%
# Read in from CSV file
with open(path, 'r') as file:
    data = file.readlines()

# %%
import csv

data_dict = {}

# Assuming "video_data.csv" is your file:
with open(path, 'r', encoding='utf-8') as f:
    reader = csv.reader(f, delimiter=',', quotechar='"')
    next(reader)  # Skip the header if there is one
    for row in reader:
        # Adjust the indices depending on your CSV's actual columns:
        vid_id    = row[0]
        text      = row[1]
        fps       = row[2]
        num_frame = row[3]
        h         = row[4]
        w         = row[5]

        data_dict[vid_id] = {
            'text': text, 
            'fps': fps, 
            'h': h, 
            'w': w, 
            'num_frame': num_frame
        }

# Now data_dict should contain the correct mappings,
# with commas inside the text field preserved.

# %%
data_dict
# Out:
# {'pexels/videos-popular/8620887': {'text': ' father carrying his son on a beach',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '384'},
#  'pexels/videos-popular/5935446': {'text': ' group of friends having a toast',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '327'},
#  'pexels/videos-popular/7187451': {'text': ' tattooed woman climbing rocks',
#   'fps': '24.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '324'},
#  'pexels/videos-popular/4305111': {'text': ' ray of the sun on the forest ground',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '1228'},
#  'pexels/videos-popular/4623273': {'text': 'Students walk along a campus sidewalk, surrounded by trees and modern buildings, while two individuals pause to chat beside a bicycle.',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '283'},
#  'pexels/videos-popular/5940459': {'text': ' woman taling in front of the class in a library',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '376'},
#  'pexels/videos-popular/4109208': {'text': 'A woman with curly hair is bent over in a living room, adjusting a cable on an entertainment system.',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '386'},
#  'pexels/videos-popular/4932585': {'text': ' slicing open a papaya',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '522'},
#  'pexels/videos-popular/5805077': {'text': ' people celebrating a birthday',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '230'},
#  'pexels/videos-popular/8688102': {'text': ' a man communicating using his laptop',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '260'},
#  'pexels/videos-popular/8891861': {'text': ' a view of a sad woman from the window',
#   'fps': '24.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '333'},
#  'pexels/videos-popular/12966266': {'text': ' interior of ancient building',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '167'},
#  'pexels/videos-popular/5970710': {'text': ' a person putting usb on the laptop',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '359'},
#  'pexels/videos-popular/7722217': {'text': ' man playing a guitar at a concert',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '167'},
#  'pexels/videos-popular/8346823': {'text': ' close up video of a person throwing clothes',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '971'},
#  'pexels/videos-popular/14949894': {'text': ' an aerial footage of beautiful houses by the beach',
#   'fps': '29.97002997002997',
#   'h': '540',
#   'w': '960',
#   'num_frame': '2049'},
#  'pexels/videos-popular/7237055': {'text': ' girl mixing colorful liquids',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '317'},
#  'pexels/videos-popular/10844252': {'text': ' close up on hands rolling clay',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '268'},
#  'pexels/videos-popular/6688371': {'text': 'A focused player contemplates their next chess move, considering the strategic positioning of the pieces on the board.',
#   'fps': '25.0',
#   'h': '1026',
#   'w': '2732',
#   'num_frame': '589'},
#  'pexels/videos-popular/4254123': {'text': ' a person walking on a dirt road',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '244'},
#  'pexels/videos-popular/4772750': {'text': ' video of woman walking on top of the rock formation',
#   'fps': '60.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '1949'},
#  'pexels/videos-popular/7125848': {'text': 'A person in a white t-shirt relaxes with earphones, holding a smartphone and a beverage, suggesting a moment of leisure or break.',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/13810196': {'text': ' flag of india waving on wind',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '354'},
#  'pexels/videos-popular/4996363': {'text': 'Tall grasses with beige tassels sway gently in the breeze, creating a serene and calming scene.',
#   'fps': '50.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '450'},
#  'pexels/videos-popular/8201302': {'text': ' people working in an office',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '213'},
#  'pexels/videos-popular/6555282': {'text': ' an anonymous person sniffing drugs',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '865'},
#  'pexels/videos-popular/4433388': {'text': ' a woman entering the room for a meeting',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '628'},
#  'pexels/videos-popular/8106407': {'text': 'Two persons stand near a weathered basketball hoop, amidst apartment buildings, with a hint of casual conversation.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '665'},
#  'pexels/videos-popular/8995469': {'text': ' a woman wearing hijab while looking at camera',
#   'fps': '59.94005994005994',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '511'},
#  'pexels/videos-popular/5206827': {'text': ' a person caressing a brown horse s head',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '553'},
#  'pexels/videos-popular/7844923': {'text': 'A person in a business suit sits on a sofa in a bright, modern space, engaged in a conversation with an out-of-focus figure nearby.',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '310'},
#  'pexels/videos-popular/12247602': {'text': ' vehicle on construction area',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '3374'},
#  'pexels/videos-popular/6000644': {'text': ' a woman walking on the streets',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '240'},
#  'pexels/videos-popular/6682072': {'text': 'A person makes breakfast in a modern kitchen, frying eggs in a black pan on a white stove with decorative tiles.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '251'},
#  'pexels/videos-popular/8384627': {'text': ' a kid playing balloon inside the tent',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '171'},
#  'pexels/videos-popular/7033413': {'text': ' woman reading a book while lying down',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/5080937': {'text': ' person hanging feet outside of car window',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '619'},
#  'pexels/videos-popular/6520284': {'text': ' paramedics going inside an ambulance',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '350'},
#  'pexels/videos-popular/10466300': {'text': ' police officers inside police car',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '655'},
#  'pexels/videos-popular/8297914': {'text': 'A person in a blue shirt carries a child in an orange shirt on their back, while another person in a floral dress reaches out towards them, against a backdrop of lush green foliage.',
#   'fps': '30.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '402'},
#  'pexels/videos-popular/8795959': {'text': 'A person sits on a bench by a shimmering lake, a vibrant rainbow arching across the sky over distant trees.',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '490'},
#  'pexels/videos-popular/8005471': {'text': ' people presenting a product design',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '724'},
#  'pexels/videos-popular/8906752': {'text': ' woman wearing hijab looking away',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '459'},
#  'pexels/videos-popular/18358675': {'text': 'Aerial view of four canoeists paddling over the crystal-clear waters, surrounded by scattered rocks.',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '369'},
#  'pexels/videos-popular/5323262': {'text': ' man and woman dancing together',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '676'},
#  'pexels/videos-popular/8325996': {'text': ' a female scientist looking into a microscope',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '344'},
#  'pexels/videos-popular/8177322': {'text': ' people doing tiptoe while wearing pointe shoes',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '434'},
#  'pexels/videos-popular/853722': {'text': 'A brown dog is hanging its head out of a moving car window, looking at a blurred landscape of trees and rocks.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '385'},
#  'pexels/videos-popular/3088697': {'text': ' rear wheel burnouts for race car at the starting point',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '498'},
#  'pexels/videos-popular/7492157': {'text': ' family smiling while looking at camera',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '275'},
#  'pexels/videos-popular/9574200': {'text': ' city road traffic night',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1124'},
#  'pexels/videos-popular/5654173': {'text': ' woman with black lipstick',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '990'},
#  'pexels/videos-popular/5501229': {'text': ' an aerial footage of a countryside',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '321'},
#  'pexels/videos-popular/15649864': {'text': ' snow light city road',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '510'},
#  'pexels/videos-popular/7246549': {'text': ' man giving gifts to hosts',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '613'},
#  'pexels/videos-popular/6561368': {'text': 'A serene scene with a cup of tea, bitten cookies, an open book, and a bouquet of yellow flowers on a white tablecloth.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '222'},
#  'pexels/videos-popular/17786279': {'text': 'A woman sits by a calm lake, gazing at the lush green hills in the distance, lost in thought.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '250'},
#  'pexels/videos-popular/4110436': {'text': ' a pregnant woman doing prenatal exercises',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '585'},
#  'pexels/videos-popular/5771298': {'text': ' woman laying in a couch',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '203'},
#  'pexels/videos-popular/8153139': {'text': ' a woman opening the window of a mobile home',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '215'},
#  'pexels/videos-popular/8680391': {'text': ' a stop motion video',
#   'fps': '26.666666666666668',
#   'h': '1080',
#   'w': '1620',
#   'num_frame': '400'},
#  'pexels/videos-popular/3046031': {'text': ' an earthworm burrowing down the compost soil',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '601'},
#  'pexels/videos-popular/4307449': {'text': ' boats docked on a harbor',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '375'},
#  'pexels/videos-popular/8217045': {'text': 'Two individuals in casual attire pose together; one stands while draping an arm over the other who is seated on a black office chair.',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '254'},
#  'pexels/videos-popular/4102916': {'text': ' revolving shot of a street during festival',
#   'fps': '29.97002997002997',
#   'h': '320',
#   'w': '568',
#   'num_frame': '2718'},
#  'pexels/videos-popular/8934026': {'text': ' a ballerina wearing her pointe shoes',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '593'},
#  'pexels/videos-popular/6886137': {'text': ' a drone footage of a coastal area of arctic ocean',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '723'},
#  'pexels/videos-popular/8927846': {'text': ' a man typing on a laptop and listening to music',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '365'},
#  'pexels/videos-popular/17520474': {'text': ' shrine of imam ali in an atmosphere of sadness',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '664'},
#  'pexels/videos-popular/852342': {'text': 'The scene shows a close-up of several beer glasses with condensation, being lifted and clinked together in a celebration.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '587'},
#  'pexels/videos-popular/4912884': {'text': ' muslim blogger making a video blog',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '456'},
#  'pexels/videos-popular/8971294': {'text': ' an elderly couple hugging and dancing outdoors',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '599'},
#  'pexels/videos-popular/10048875': {'text': ' a person using a pasta maker',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '967'},
#  'pexels/videos-popular/5703369': {'text': ' presenting a gingerbread cookie',
#   'fps': '30.0',
#   'h': '3744',
#   'w': '2160',
#   'num_frame': '592'},
#  'pexels/videos-popular/8655370': {'text': ' a person talking to the kids sitting on a chair',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '346'},
#  'pexels/videos-popular/9320565': {'text': ' aerial shot of a flag',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '392'},
#  'pexels/videos-popular/5854069': {'text': 'A person stands between two walls, with an ornate building facade visible in the background.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '760'},
#  'pexels/videos-popular/11610221': {'text': ' birds eye view of beach in city',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '413'},
#  'pexels/videos-popular/7307220': {'text': ' aerial view of the sea with a light house and ships sailing',
#   'fps': '29.97002997002997',
#   'h': '1974',
#   'w': '4096',
#   'num_frame': '746'},
#  'pexels/videos-popular/8125089': {'text': ' a jet bridge attaching to an aircraft',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '543'},
#  'pexels/videos-popular/5353620': {'text': ' people enjoying paddle boats in the lake',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '436'},
#  'pexels/videos-popular/18101976': {'text': 'A car is lifted up on a mechanical lift, exposing its undercarriage and wheel for maintenance or inspection in a garage.',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '166'},
#  'pexels/videos-popular/5963476': {'text': 'A serene scene of a rocky creek with gentle ripples flowing through the forest.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '525'},
#  'pexels/videos-popular/5608047': {'text': ' a pod of dolphins in the sea',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '310'},
#  'pexels/videos-popular/15415330': {'text': 'A lush green field surrounded by trees with a ski lift leading up the mountain.',
#   'fps': '30.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '679'},
#  'pexels/videos-popular/10431986': {'text': ' garlic cloves in boiling water',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '345'},
#  'pexels/videos-popular/8866090': {'text': ' a man cleaning a mirror',
#   'fps': '24.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '335'},
#  'pexels/videos-popular/6715620': {'text': 'Two people are toasting with wine glasses over a table with oranges, against a backdrop of a winter landscape and fairy lights.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '280'},
#  'pexels/videos-popular/7269150': {'text': ' a deejay control the mixing panel',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '876'},
#  'pexels/videos-popular/3151465': {'text': ' drone footage of sports field',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '1263'},
#  'pexels/videos-popular/8847914': {'text': 'Two individuals stand conversing in a modern conference room with an American flag, documents on the table, and translucent curtains diffusing natural light.',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '431'},
#  'pexels/videos-popular/7278328': {'text': ' workmates talking in the coffee area',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '235'},
#  'pexels/videos-popular/4729589': {'text': ' a woman cutting a tile',
#   'fps': '60.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '974'},
#  'pexels/videos-popular/10186936': {'text': ' hand touching plasma ball',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '2700'},
#  'pexels/videos-popular/8551098': {'text': ' coworkers talking while on an escalator',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/7200766': {'text': ' women talking while sitting',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1002'},
#  'pexels/videos-popular/8858900': {'text': ' close up of garlic cloves',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '489'},
#  'pexels/videos-popular/7574513': {'text': ' a teacher and little girl are playing ukelele at home',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '633'},
#  'pexels/videos-popular/7004479': {'text': 'A worker in a reflective vest and gloves operates a machine that wraps bundles of pine branches on a conveyor belt, leaving behind scattered soil.',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '5365'},
#  'pexels/videos-popular/5745614': {'text': ' gift giving on christmas',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '464'},
#  'pexels/videos-popular/5452584': {'text': 'Snowflakes fall gently onto a grassy field, covering the ground and bushes with a thin layer of white, while a fence and bare trees line the background.',
#   'fps': '30.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '934'},
#  'pexels/videos-popular/16835004': {'text': 'A figure stands by a window under a hanging light, strumming an acoustic guitar, beside a camera, in a room with a green wall and artistic decorations.',
#   'fps': '24.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '411'},
#  'pexels/videos-popular/8925160': {'text': 'The image captures a relaxed individual gazing towards a serene water body, bathed in the warm glow of sunset.',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '157'},
#  'pexels/videos-popular/9242980': {'text': ' a family eating together',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '920'},
#  'pexels/videos-popular/7645415': {'text': ' mother and daughter looking at vinyl records',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '933'},
#  'pexels/videos-popular/6940534': {'text': ' woman stretching in the studio',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '292'},
#  'pexels/videos-popular/17799960': {'text': ' mayotte swimming above beautiful corals',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '913'},
#  'pexels/videos-popular/8907333': {'text': 'A person in a black hijab is touching the shoulder of an individual wearing a black shirt, gesturing comfort or support.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '548'},
#  'pexels/videos-popular/8939802': {'text': ' woman wearing hijab talking',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '321'},
#  'pexels/videos-popular/8327144': {'text': ' scientist dropping a liquid in a glass tube',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '474'},
#  'pexels/videos-popular/16630930': {'text': 'A cargo ship is docked at a port beside a large storage building, with cranes ready to load and unload containers.',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '618'},
#  'pexels/videos-popular/7321225': {'text': 'The image captures a desert landscape with primitive straw huts, mountains in the background, and a person walking through the sandy terrain.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '308'},
#  'pexels/videos-popular/8544138': {'text': ' a volunteer holding a plant',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '252'},
#  'pexels/videos-popular/9406708': {'text': ' sharks in a saltwater aquarium',
#   'fps': '29.97002997002997',
#   'h': '2048',
#   'w': '996',
#   'num_frame': '375'},
#  'pexels/videos-popular/4961909': {'text': ' siblings sitting on a bed reading a book',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '377'},
#  'pexels/videos-popular/12719798': {'text': ' drone footage of town',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '263'},
#  'pexels/videos-popular/9070181': {'text': ' a group of men having teamwork',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '180'},
#  'pexels/videos-popular/8321912': {'text': ' an elderly man looking at a grandfather clock',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '305'},
#  'pexels/videos-popular/9057560': {'text': ' a woman listening to music while holding her mobile phone',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '398'},
#  'pexels/videos-popular/6646683': {'text': 'A volunteer in a white t-shirt pushes a person in a wheelchair outside a building, near a closed gate with address numbers 138 and 140.',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '218'},
#  'pexels/videos-popular/6799024': {'text': ' a woman in deep thought while drinking a coffee',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '367'},
#  'pexels/videos-popular/8834657': {'text': ' men talking on a basketball court',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '548'},
#  'pexels/videos-popular/7826156': {'text': ' video of birthday decorations',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '265'},
#  'pexels/videos-popular/3904983': {'text': ' elderly man wearing his shoe',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '423'},
#  'pexels/videos-popular/7667558': {'text': 'A group of dancers in black attire performs a coordinated floor routine against a minimalist backdrop.',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '650'},
#  'pexels/videos-popular/8164313': {'text': ' a man looking through window',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '263'},
#  'pexels/videos-popular/4118680': {'text': 'A silver NOMA fan with spinning blades sits on a brown carpeted floor, providing cool air to the room.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '128'},
#  'pexels/videos-popular/2878097': {'text': "A vast body of water sits below a dam with hills and a serene sky in the background, as two small figures walk along the dam's crest.",
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '643'},
#  'pexels/videos-popular/854077': {'text': 'A fiery blaze crackles beneath a metal grill, casting a warm glow and sending sparks upwards into the darkness.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '358'},
#  'pexels/videos-popular/8439610': {'text': ' woman writing on notebook',
#   'fps': '50.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '778'},
#  'pexels/videos-popular/14234744': {'text': ' long road in between trees',
#   'fps': '24.0',
#   'h': '1440',
#   'w': '2732',
#   'num_frame': '299'},
#  'pexels/videos-popular/6962446': {'text': 'A woman in a white sweater stands in a sunlit forest, gesturing during a discussion with a man in a beige shirt holding a coffee cup.',
#   'fps': '50.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '392'},
#  'pexels/videos-popular/4106408': {'text': ' a man climbing up wall',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '472'},
#  'pexels/videos-popular/6750877': {'text': ' person having a hot stone massage',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '240'},
#  'pexels/videos-popular/5041585': {'text': 'In a spacious, well-lit room, a person practices yoga on a mat, arms extended upwards, amidst minimalist decor and large windows.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '631'},
#  'pexels/videos-popular/9153809': {'text': ' a person standing near the beehive',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '240'},
#  'pexels/videos-popular/8625273': {'text': ' an elderly woman touching her skin',
#   'fps': '25.0',
#   'h': '1440',
#   'w': '2732',
#   'num_frame': '3409'},
#  'pexels/videos-popular/11333034': {'text': ' snow and ice around stream',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1799'},
#  'pexels/videos-popular/7905112': {'text': 'A bird flies over the calm ocean waves hitting the sandy shore as the sun begins to set.',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '257'},
#  'pexels/videos-popular/11613219': {'text': ' town seen from birds eye view',
#   'fps': '60.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '3391'},
#  'pexels/videos-popular/9151051': {'text': ' aerial footage of agricultural lands',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '821'},
#  'pexels/videos-popular/5403934': {'text': ' penguins waddling on shore',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '768'},
#  'pexels/videos-popular/17046753': {'text': 'A person adorned with a patterned headscarf and beaded necklace stretches out an arm amidst a lush, green forest setting.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '538'},
#  'pexels/videos-popular/6862867': {'text': ' woman checking the stock market while eating raspberries',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '955'},
#  'pexels/videos-popular/4704685': {'text': ' riding a jet ski on a lake',
#   'fps': '29.97002997002997',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '1748'},
#  'pexels/videos-popular/11038543': {'text': ' footage of cougar puma concolor in forest',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '375'},
#  'pexels/videos-popular/19025792': {'text': 'A punter skillfully navigates a wooden boat down a serene river, flanked by lush willow trees and historic architecture under a partly cloudy sky.',
#   'fps': '30.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '482'},
#  'pexels/videos-popular/5481771': {'text': ' young man washing hands with his dog',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '135'},
#  'pexels/videos-popular/5385833': {'text': ' woman typing on the laptop',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '333'},
#  'pexels/videos-popular/4085341': {'text': ' nature flowers garden beautiful',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '175'},
#  'pexels/videos-popular/3873086': {'text': ' a young woman dancing',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '231'},
#  'pexels/videos-popular/8135341': {'text': 'A person in a cream hijab and white blouse is seated at a glossy orange table, hands gently placed on the surface, reflecting a serene mood amidst an eclectic, whimsically-decorated room.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '306'},
#  'pexels/videos-popular/8126721': {'text': ' fashionable man walking at the street',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '356'},
#  'pexels/videos-popular/5926024': {'text': ' boy walking on park',
#   'fps': '24.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '554'},
#  'pexels/videos-popular/8298627': {'text': ' a shirtless man getting soap',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '610'},
#  'pexels/videos-popular/8451708': {'text': ' woman hugging another woman',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '507'},
#  'pexels/videos-popular/11564291': {'text': ' a loaded grain truck entering a processing plant',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '519'},
#  'pexels/videos-popular/16224282': {'text': ' sea city landscape beach',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '312'},
#  'pexels/videos-popular/6658630': {'text': 'A person examines a vintage camera beside another camera on a wooden table, softly illuminated by candlelight.',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '211'},
#  'pexels/videos-popular/10929145': {'text': ' tokyo skyline seen from shinobazu pond',
#   'fps': '29.97002997002997',
#   'h': '1884',
#   'w': '1060',
#   'num_frame': '436'},
#  'pexels/videos-popular/6637292': {'text': 'Two snowboarders stand with their boards on a snowy hill, overlooking a valley with ski lifts and forested mountains under a cloudy sky.',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '396'},
#  'pexels/videos-popular/16131837': {'text': 'A closeup view of wild grass with a few purple flowers scattered amidst the greenery, showing the beauty of nature.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '497'},
#  'pexels/videos-popular/13554476': {'text': ' curtain flying on wind',
#   'fps': '30.0',
#   'h': '3240',
#   'w': '2160',
#   'num_frame': '302'},
#  'pexels/videos-popular/6436608': {'text': 'From above, a circular sinkhole filled with water and surrounded by lush greenery, with waves crashing against the rocks.',
#   'fps': '60.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '822'},
#  'pexels/videos-popular/7437129': {'text': ' an old castle on top of a mountain',
#   'fps': '29.97002997002997',
#   'h': '1974',
#   'w': '4096',
#   'num_frame': '323'},
#  'pexels/videos-popular/8154495': {'text': ' woman fixing her hair',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '637'},
#  'pexels/videos-popular/7552523': {'text': ' two men bullying a co worker',
#   'fps': '50.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '792'},
#  'pexels/videos-popular/15314973': {'text': ' royal cliff beach hotel in pattaya thailand',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '159'},
#  'pexels/videos-popular/8102248': {'text': ' a woman smelling a carnation flower while posing',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '828'},
#  'pexels/videos-popular/12097524': {'text': ' city downtown from birds eye view',
#   'fps': '59.94005994005994',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '1929'},
#  'pexels/videos-popular/17484076': {'text': ' river stream on a sunny day',
#   'fps': '30.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '1166'},
#  'pexels/videos-popular/6264218': {'text': ' aerial view of person harvesting rice',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '938'},
#  'pexels/videos-popular/12892445': {'text': ' rusty vintage car wreck close up',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '107'},
#  'pexels/videos-popular/7814422': {'text': ' a plant with blue flowers in a yellow mug',
#   'fps': '30.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '309'},
#  'pexels/videos-popular/8421260': {'text': ' man strolling a baby',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '239'},
#  'pexels/videos-popular/9591143': {'text': ' low angle shot of woman drinking coffee',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '881'},
#  'pexels/videos-popular/5019201': {'text': ' ants feeding on a dead spider',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '473'},
#  'pexels/videos-popular/6320124': {'text': ' couple chilling out on rock formation',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '99'},
#  'pexels/videos-popular/4334570': {'text': ' drone shot of a waterfalls in the mountain',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1026'},
#  'pexels/videos-popular/10261081': {'text': ' a person typing on laptop',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '904'},
#  'pexels/videos-popular/5745609': {'text': ' a family hugging each other',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '366'},
#  'pexels/videos-popular/18437014': {'text': "A red race car's interior shows a roll cage, racing seat, and harness, highlighting the vehicle's high-performance nature and safety features.",
#   'fps': '59.94005994005994',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '420'},
#  'pexels/videos-popular/4928374': {'text': 'A person sits at a wooden desk, intently interacting with a large desktop monitor in a room with exposed brick walls and a bookshelf.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '274'},
#  'pexels/videos-popular/7655452': {'text': ' a man crushing a plastic bottle',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '343'},
#  'pexels/videos-popular/8496456': {'text': ' beautiful curly woman looking at camera',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '213'},
#  'pexels/videos-popular/7803911': {'text': ' couple taking photo using smartphone',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '362'},
#  'pexels/videos-popular/6688635': {'text': ' a man dancing with giant chess pieces',
#   'fps': '25.0',
#   'h': '2048',
#   'w': '1080',
#   'num_frame': '923'},
#  'pexels/videos-popular/6970269': {'text': ' a child slicing a broccoli',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '499'},
#  'pexels/videos-popular/8478039': {'text': ' a person spooning a cupcake',
#   'fps': '23.976023976023978',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '268'},
#  'pexels/videos-popular/4929934': {'text': ' young girl playing with the flour while baking',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '368'},
#  'pexels/videos-popular/8076057': {'text': ' pregnant woman is dancing',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '483'},
#  'pexels/videos-popular/15881178': {'text': 'A tranquil coastal scene with numerous boats floating on calm waters under a softly lit sky, as gentle waves lap the shore.',
#   'fps': '24.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '464'},
#  'pexels/videos-popular/5920299': {'text': ' man preparing food on a wooden chopping board',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '538'},
#  'pexels/videos-popular/7274602': {'text': ' depressed woman on a chair',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '1127'},
#  'pexels/videos-popular/6079616': {'text': ' drone footage of an indoor football field',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '286'},
#  'pexels/videos-popular/5909588': {'text': ' a close up video of grass on the lake',
#   'fps': '24.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '320'},
#  'pexels/videos-popular/4976968': {'text': ' a person putting a black cumin on the food',
#   'fps': '30.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '231'},
#  'pexels/videos-popular/18114963': {'text': 'An aerial view of a town with a bridge crossing a river, connecting the densely packed residential areas on either side.',
#   'fps': '59.94005994005994',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1114'},
#  'pexels/videos-popular/5527128': {'text': ' back view of mother and daughter walking with fruit basket',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '288'},
#  'pexels/videos-popular/5801985': {'text': ' a person peeling off the leaves of a cauliflower',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '300'},
#  'pexels/videos-popular/7579559': {'text': ' man evaluating the market',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '545'},
#  'pexels/videos-popular/4473145': {'text': ' man opening wooden case with paint tubes',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '520'},
#  'pexels/videos-popular/7612018': {'text': ' the silhouette of a man singing',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '380'},
#  'pexels/videos-popular/6041711': {'text': ' static lines on a screen',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1802'},
#  'pexels/videos-popular/6622665': {'text': ' soybean crops in the farmland',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '516'},
#  'pexels/videos-popular/12227744': {'text': ' woman in jacket on ground road',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '149'},
#  'pexels/videos-popular/6754832': {'text': ' a person using soldering iron',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '658'},
#  'pexels/videos-popular/9853507': {'text': 'A person in a red blazer gestures with their hands adorned with jewelry over a document, indicating a discussion or explanation in progress.',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '541'},
#  'pexels/videos-popular/7147261': {'text': ' group of friends staying at the lifeguard tower',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '406'},
#  'pexels/videos-popular/6125528': {'text': ' a prisoner and a cop arguing',
#   'fps': '30.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '215'},
#  'pexels/videos-popular/7224359': {'text': 'A person in a gray jacket is taking a picture with a smartphone of a black cast iron pan and other kitchen items on a wooden table.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '1094'},
#  'pexels/videos-popular/6024454': {'text': 'A person wearing a chunky beige sweater and black boots is sitting with their legs crossed on a patterned chair behind a wooden table with ornate metal legs.',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '131'},
#  'pexels/videos-popular/6149970': {'text': ' young couple holding hands and talking while looking at each other',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '330'},
#  'pexels/videos-popular/3913493': {'text': ' a person playing a game using a smartphone',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '190'},
#  'pexels/videos-popular/10435537': {'text': ' a man giving a woman a piggyback ride',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '627'},
#  'pexels/videos-popular/6894121': {'text': 'A person is preparing food in disposable containers, arranging broccoli, corn, and bacon in an organized manner.',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '389'},
#  'pexels/videos-popular/7148124': {'text': ' video of a man smiling looking at camera',
#   'fps': '24.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '266'},
#  'pexels/videos-popular/10863232': {'text': 'A narrow, empty road stretches ahead, lined by tall, swaying grass, leading towards a solitary tree on the horizon.',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1071'},
#  'pexels/videos-popular/18826240': {'text': 'A blue train travels along curving tracks surrounded by lush greenery, with overhead electrical wires powering its journey.',
#   'fps': '29.97002997002997',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '1696'},
#  'pexels/videos-popular/852362': {'text': 'A classic truck with its hood open is broken down on a street, as other vehicles pass by in the background.',
#   'fps': '23.976023976023978',
#   'h': '720',
#   'w': '1280',
#   'num_frame': '960'},
#  'pexels/videos-popular/4606793': {'text': ' person riding a motorcycle on road',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '2923'},
#  'pexels/videos-popular/14596718': {'text': ' tractor on field in vineyard',
#   'fps': '25.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '298'},
#  'pexels/videos-popular/19093952': {'text': 'A ferry boat glides across the calm waters of a misty bay, framed by rocky shores and distant mountains.',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '554'},
#  'pexels/videos-popular/17642557': {'text': ' agricultura pulverizacao maquinas tratores',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '603'},
#  'pexels/videos-popular/7845424': {'text': ' an angry boss at a meeting',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '194'},
#  'pexels/videos-popular/5727385': {'text': ' mom and daughter decorating a cake with chocolate',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '288'},
#  'pexels/videos-popular/5722175': {'text': ' father and daughter on christmas shopping',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/3253081': {'text': ' man showing a note on his forehead',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '503'},
#  'pexels/videos-popular/8331806': {'text': ' a woman drinking tea on a teacup sitting on the ground',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '568'},
#  'pexels/videos-popular/6773060': {'text': ' a cracked egg and a spoon',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '228'},
#  'pexels/videos-popular/16022331': {'text': 'A triangular-shaped building with a glass front sits atop a grassy hill, surrounded by small white bags arranged in rows, under a tree with colorful flags.',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '143'},
#  'pexels/videos-popular/5022750': {'text': ' the beautiful skyline of mumbai',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '401'},
#  'pexels/videos-popular/4808628': {'text': ' a crowd of people painting mural on the street',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '226'},
#  'pexels/videos-popular/4265284': {'text': ' woman drinking water from water bottle',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '424'},
#  'pexels/videos-popular/6180920': {'text': ' man sunbathing while sitting on the staircase',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '306'},
#  'pexels/videos-popular/8889271': {'text': ' girl lying down on top of a piano while looking at camera',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '284'},
#  'pexels/videos-popular/9065051': {'text': 'Two individuals engage in a conversation in a modern living room with one gesturing while seated on a black leather couch and the other taking notes.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '229'},
#  'pexels/videos-popular/13883201': {'text': ' woods and rock formations in countryside',
#   'fps': '24.0',
#   'h': '540',
#   'w': '960',
#   'num_frame': '699'},
#  'pexels/videos-popular/12295942': {'text': 'A person in a polka-dot top fries golden-brown delicacies in bubbling oil, amidst an open-air setting with bystanders.',
#   'fps': '60.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '652'},
#  'pexels/videos-popular/7171548': {'text': 'A person in a dark jacket and white shirt holds a green rose stem between their fingers, inspecting it closely.',
#   'fps': '50.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '485'},
#  'pexels/videos-popular/7009760': {'text': ' close up video of scout badges',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '386'},
#  'pexels/videos-popular/15553678': {'text': 'A classic orange car cruises past a stone archway as dusk colors the sky in hues of pink and blue.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '1621'},
#  'pexels/videos-popular/13519115': {'text': 'A dragonfly perches delicately on a slender twig, its translucent wings shimmering in the dappled sunlight filtering through the leafy green backdrop.',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '897'},
#  'pexels/videos-popular/8882926': {'text': ' back view footage of people shooting balls in a a ring of an arcade machine',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '641'},
#  'pexels/videos-popular/6604356': {'text': ' couple buying pizza to go',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '280'},
#  'pexels/videos-popular/6193801': {'text': ' santa claus finger pointing in a direction',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '592'},
#  'pexels/videos-popular/11354591': {'text': ' close up on cutting sunflower from field',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '253'},
#  'pexels/videos-popular/5438886': {'text': 'A man in a grey suit and tie flipping through a document on his desk with one hand while holding a pen in the other hand.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '697'},
#  'pexels/videos-popular/7865546': {'text': 'People are clapping and celebrating in a room decorated with golden balloons, with a sense of motion and cheerfulness.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '295'},
#  'pexels/videos-popular/8731513': {'text': ' a man signing an agreement',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '391'},
#  'pexels/videos-popular/4836873': {'text': ' a dog walking on the beach',
#   'fps': '29.97002997002997',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '1223'},
#  'pexels/videos-popular/7297924': {'text': 'A man in a blue shirt sits on the grass, holding his head in his hands, possibly in distress or deep thought.',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '279'},
#  'pexels/videos-popular/9025792': {'text': ' twin sisters getting paper for an online class',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '184'},
#  'pexels/videos-popular/4814493': {'text': ' view of moon through leaves',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1295'},
#  'pexels/videos-popular/12239796': {'text': ' clouds over city on shore',
#   'fps': '50.0',
#   'h': '1440',
#   'w': '2550',
#   'num_frame': '1563'},
#  'pexels/videos-popular/7640944': {'text': 'In a modern kitchen with pendant lights, an individual is preparing a meal on a black countertop surrounded by brick and dark shelving.',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '938'},
#  'pexels/videos-popular/7704095': {'text': ' a flower and an egg tray',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '395'},
#  'pexels/videos-popular/3723647': {'text': 'A person wearing black boots walks on a rocky terrain with scattered red and brown stones, some submerged in shallow water.',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '212'},
#  'pexels/videos-popular/5464952': {'text': ' a man sitting on his bike',
#   'fps': '50.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '324'},
#  'pexels/videos-popular/4872289': {'text': ' drone footage of vehicles traveling on highway',
#   'fps': '59.94005994005994',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '1147'},
#  'pexels/videos-popular/6865221': {'text': ' a woman removing lint on her clothes',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '657'},
#  'pexels/videos-popular/8576587': {'text': ' cute boy in white top eating a snack',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '362'},
#  'pexels/videos-popular/6667264': {'text': ' a person leaving a package at the door',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '298'},
#  'pexels/videos-popular/8442672': {'text': 'A woman in a white dress is laying on the grass, surrounded by a darker green path that splits.',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '535'},
#  'pexels/videos-popular/3997855': {'text': 'A hand is placed inside a UV nail lamp, curing the freshly applied gel polish with a bright blue light.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '489'},
#  'pexels/videos-popular/7592686': {'text': ' video of a bread',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '408'},
#  'pexels/videos-popular/6538095': {'text': ' drone footage of low tide',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '542'},
# ...
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '1065'},
#  'pexels/videos-popular/3975069': {'text': 'An ancient fortress adorned with glowing lights stands tall, surrounded by a protective wall and nested in the twilight landscape.',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '413'},
#  'pexels/videos-popular/7622291': {'text': 'A person in a leather jacket rides a black horse through a field, holding the reins confidently.',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '633'},
#  'pexels/videos-popular/17158280': {'text': ' lido beach',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '753'},
#  'pexels/videos-popular/9374852': {'text': ' a couple sleeping together',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '520'},
#  'pexels/videos-popular/6288848': {'text': ' sprinkling pepper on a dish',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '265'},
#  'pexels/videos-popular/6271250': {'text': ' woman placing ornaments on christmas tree',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '488'},
#  'pexels/videos-popular/18397369': {'text': ' men playing street basketball on basketball court',
#   'fps': '59.94005994005994',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '2140'},
#  'pexels/videos-popular/6156835': {'text': 'Three individuals are closely positioned, with one wearing reindeer antlers and another in a Santa hat, while the third person embraces a large teddy bear.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '238'},
#  'pexels/videos-popular/7231133': {'text': ' women reading magazine while having conversation',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '1365'},
#  'pexels/videos-popular/6265447': {'text': ' couple posing while on the snow',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '469'},
#  'pexels/videos-popular/7945244': {'text': ' female graduates taking a group selfie',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '401'},
#  'pexels/videos-popular/6501872': {'text': ' close up of a person covering a bite block with plastic',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '259'},
#  'pexels/videos-popular/6280330': {'text': ' a person roasting the coffee beans',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '175'},
#  'pexels/videos-popular/7319523': {'text': 'A stone terrace with three sculptures overlooks a river and a busy street, with a man enjoying the view below.',
#   'fps': '29.97002997002997',
#   'h': '1974',
#   'w': '4096',
#   'num_frame': '263'},
#  'pexels/videos-popular/5780700': {'text': 'A chef wearing black gloves prepares vegetable skewers with sliced red and yellow bell peppers, and corn on a white cutting board.',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '371'},
#  'pexels/videos-popular/4502464': {'text': ' using a bunch of flowers for interior decoration',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '579'},
#  'pexels/videos-popular/6226747': {'text': 'Two individuals in matching outfits embrace amidst a staged indoor nature scene, with lush greenery underfoot and a warm light illuminating from a corner.',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '599'},
#  'pexels/videos-popular/6715672': {'text': ' a couple embracing in bed',
#   'fps': '25.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '184'},
#  'pexels/videos-popular/5471474': {'text': ' time lapse video of a cloudy sky',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '762'},
#  'pexels/videos-popular/8756628': {'text': ' a man posing on a washing machine',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '823'},
#  'pexels/videos-popular/5743113': {'text': 'A person stands writing in a notebook beside a rack of clothes, with accessories and packaged boxes nearby, suggesting a fashion inventory or planning setting.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '287'},
#  'pexels/videos-popular/18974940': {'text': 'An ornate mosque with a large chandelier, viewed through open doors, with visitors walking in the courtyard.',
#   'fps': '60.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '432'},
#  'pexels/videos-popular/5356837': {'text': ' closeup of an artificial dentures',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '366'},
#  'pexels/videos-popular/7683451': {'text': 'Two individuals are engrossed in a game of poker, surrounded by cards, chips, and dice on a table, under an abstract art piece.',
#   'fps': '30.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '283'},
#  'pexels/videos-popular/8926500': {'text': ' elderly man playing the recorder',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '486'},
#  'pexels/videos-popular/8927848': {'text': ' a man looking at papers',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '505'},
#  'pexels/videos-popular/11298654': {'text': ' wetland at the edge of forest',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '773'},
#  'pexels/videos-popular/4104937': {'text': ' family eating together at home',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '407'},
#  'pexels/videos-popular/6964545': {'text': ' woman assisting a man',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '475'},
#  'pexels/videos-popular/11771548': {'text': ' low angle view of the holy trinity church in gervyaty',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '421'},
#  'pexels/videos-popular/17932088': {'text': 'Two people on a jet ski speed down a tranquil river, surrounded by lush greenery and towering mountains.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '467'},
#  'pexels/videos-popular/12788797': {'text': "A person leans against a brick wall with a sun-shaped decor, holding a phone and carrying a tote bag with 'New York' written on it.",
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/7168646': {'text': 'The towering Burj Khalifa stands tall among the palm trees under the bright blue sky.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '496'},
#  'pexels/videos-popular/6481466': {'text': ' kids preparing a salad',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '214'},
#  'pexels/videos-popular/7706074': {'text': ' woman carrying a thermal bag',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '331'},
#  'pexels/videos-popular/10499655': {'text': ' man putting hand on tomb and walking away',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '816'},
#  'pexels/videos-popular/4866050': {'text': ' woman relaxation bookshop young',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '194'},
#  'pexels/videos-popular/7800089': {'text': 'People are gathered on a couch, exchanging colorful, wrapped gifts, with bright balloons in the background, suggesting a celebration.',
#   'fps': '25.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '209'},
#  'pexels/videos-popular/5088109': {'text': ' little girl doing her homework',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '383'},
#  'pexels/videos-popular/8116279': {'text': ' a woman with small flowers on her eyebrows',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '470'},
#  'pexels/videos-popular/9199204': {'text': ' a woman sitting at the desk',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '784'},
#  'pexels/videos-popular/9346226': {'text': 'Two people are standing by a colorful street flower stall, with one person reaching out to touch the vibrant blooms on display.',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/8107405': {'text': ' person pouring a milk into the bowl of cereal',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '354'},
#  'pexels/videos-popular/12936678': {'text': ' toyota fortuner on beach',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '592'},
#  'pexels/videos-popular/12715008': {'text': ' video of white cockatoo',
#   'fps': '29.97002997002997',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '490'},
#  'pexels/videos-popular/11825413': {'text': ' eruption of volcano on iceland',
#   'fps': '60.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '1063'},
#  'pexels/videos-popular/4115281': {'text': 'A person sits at a wooden table with a cup of tea, surrounded by crumpled tissues and an empty tissue box, indicating a cold or flu.',
#   'fps': '50.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '802'},
#  'pexels/videos-popular/8434057': {'text': ' girl petting a furry rabbit in bed',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '430'},
#  'pexels/videos-popular/7092062': {'text': ' students cheating during an exam',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '361'},
#  'pexels/videos-popular/5923285': {'text': ' close up video of person using laptop',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '403'},
#  'pexels/videos-popular/7648331': {'text': ' a man doing a presentation in a meeting',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '227'},
#  'pexels/videos-popular/6876324': {'text': ' woman drinking while working on her laptop',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '633'},
#  'pexels/videos-popular/8120848': {'text': ' a beautiful woman wearing a hijab',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '516'},
#  'pexels/videos-popular/13868599': {'text': 'A stone pathway leads to a historic fortress, flying a national flag, surrounded by trees and visitors under a partly cloudy sky.',
#   'fps': '29.97002997002997',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '176'},
#  'pexels/videos-popular/8226086': {'text': ' a woman with eyes closed',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '354'},
#  'pexels/videos-popular/10495957': {'text': ' friends having picnic together under the tree in the beach',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '1050'},
#  'pexels/videos-popular/16401396': {'text': 'Delicate purple flowers bloom on slender green stems against a blurred backdrop of a vibrant garden.',
#   'fps': '60.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '516'},
#  'pexels/videos-popular/8667841': {'text': ' a person weighing powder medicine on a iron scale',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '837'},
#  'pexels/videos-popular/7218874': {'text': ' father and daughter playing on the floor',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '951'},
#  'pexels/videos-popular/3463042': {'text': ' burning fire woods on an installed heater',
#   'fps': '29.97002997002997',
#   'h': '1440',
#   'w': '1920',
#   'num_frame': '304'},
#  'pexels/videos-popular/8963677': {'text': ' a woman in a hard hat and safety vest posing while holding a tablet',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '162'},
#  'pexels/videos-popular/12044424': {'text': ' bird on stone during rainfall',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '870'},
#  'pexels/videos-popular/7312394': {'text': 'A child in a blue dress plays with a wooden toy, while a person in a black sweater observes, and another in a red hoodie looks on.',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '588'},
#  'pexels/videos-popular/5147312': {'text': ' making toasts and black coffee for breakfast',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '1033'},
#  'pexels/videos-popular/6607121': {'text': ' woman in white sweater reading a magazine while touching her dog',
#   'fps': '23.976023976023978',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '215'},
#  'pexels/videos-popular/15619070': {'text': 'The panoramic view of a bustling city surrounded by green mountains, with a clear blue sky overhead.',
#   'fps': '24.0',
#   'h': '1440',
#   'w': '2560',
#   'num_frame': '330'},
#  'pexels/videos-popular/11887093': {'text': ' sparks flying while a man is working with metal',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '325'},
#  'pexels/videos-popular/10006427': {'text': ' aerial view on melbourne from suburbs',
#   'fps': '29.97002997002997',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '1518'},
#  'pexels/videos-popular/7603638': {'text': ' a girl posing for the camera',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '226'},
#  'pexels/videos-popular/6964207': {'text': ' woman eating popcorn in bed',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '241'},
#  'pexels/videos-popular/4336579': {'text': ' election flags paraphernalia sways by the wind blow',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '180'},
#  'pexels/videos-popular/7325046': {'text': ' four women photo shooting in studio',
#   'fps': '25.0',
#   'h': '2880',
#   'w': '2160',
#   'num_frame': '560'},
#  'pexels/videos-popular/6687954': {'text': 'A person sits in bed holding a glass cup, amidst a serene setting with soft lighting and striped bedding.',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '354'},
#  'pexels/videos-popular/3779415': {'text': ' tracking a car travelling on a road in wilderness',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '937'},
#  'pexels/videos-popular/7235988': {'text': ' man and woman holding big balloons',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '288'},
#  'pexels/videos-popular/7820510': {'text': ' a man signing a registration form',
#   'fps': '25.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '463'},
#  'pexels/videos-popular/7424094': {'text': ' elderly man drinking wine',
#   'fps': '29.97002997002997',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '676'},
#  'pexels/videos-popular/8499663': {'text': ' woman training her dog in the rain',
#   'fps': '24.0',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '388'},
#  'pexels/videos-popular/15314949': {'text': 'An aerial view captures a vibrant green resort with red rooftops bordered by a beach with turquoise waters and boats gliding.',
#   'fps': '30.0',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '194'},
#  'pexels/videos-popular/13838022': {'text': ' green hills in birds eye view',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '166'},
#  'pexels/videos-popular/8431899': {'text': ' woman in a green bathtub',
#   'fps': '25.0',
#   'h': '4096',
#   'w': '2160',
#   'num_frame': '740'},
#  'pexels/videos-popular/7058610': {'text': ' a woman talking on the phone',
#   'fps': '23.976023976023978',
#   'h': '3840',
#   'w': '2160',
#   'num_frame': '240'},
#  'pexels/videos-popular/3225909': {'text': ' a bird perched on a no swimming allowed sign board',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '160'},
#  'pexels/videos-popular/11601849': {'text': ' back view of a mclaren sports car in a forest',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '4096',
#   'num_frame': '5148'},
#  'pexels/videos-popular/8996080': {'text': ' time lapse video of a road and cars',
#   'fps': '30.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '277'},
#  'pexels/videos-popular/7547024': {'text': ' couple lying down while holding hands',
#   'fps': '25.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '223'},
#  'pexels/videos-popular/14549646': {'text': ' a group of people making a toast during a meal',
#   'fps': '25.0',
#   'h': '1920',
#   'w': '1080',
#   'num_frame': '96'},
#  'pexels/videos-popular/7980091': {'text': ' close up shot of a kettle whistling',
#   'fps': '24.0',
#   'h': '2160',
#   'w': '3840',
#   'num_frame': '816'},
#  'pexels/videos-popular/8064130': {'text': ' a person holding a cup with fire',
#   'fps': '23.976023976023978',
#   'h': '1080',
#   'w': '1920',
#   'num_frame': '324'},
#  ...}

# %%
# Filter data_dict to only include videos in horizontal manner by calculating aspect ratio, and short videos with less than 50 frames, and print out message which video is filtered for which reason
filtered_data_dict = {}
asp_cnter = 0
frame_cnter = 0
for vid_id, info in tqdm(data_dict.items()):
    h = float(info['h'])
    w = float(info['w'])
    num_frame = int(info['num_frame'])
    aspect_ratio = w / h
    if aspect_ratio >= 1.5 and num_frame > 50:
        filtered_data_dict[vid_id] = info
    else:
        if aspect_ratio < 1.5:
            # print(f'Filtered video {vid_id} because of aspect ratio {aspect_ratio}')
            asp_cnter += 1
        if num_frame < 50:
            # print(f'Filtered video {vid_id} because of num_frame {num_frame}')
            frame_cnter += 1
print(f'Filtered {asp_cnter} videos because of aspect ratio, and {frame_cnter} videos because of num_frame')
# Out:
#  31%|███       | 121563/394468 [00:00<00:00, 1215515.24it/s]
# 100%|██████████| 394468/394468 [00:00<00:00, 1289382.38it/s]
# Filtered 110286 videos because of aspect ratio, and 10 videos because of num_frame

# %%
# Write filtered data_dict to a new CSV file
new_path = '/mnt/carpedkm_data/image_gen_ds/second_stage_video_train'
os.makedirs(new_path, exist_ok=True)

# %%
# save as json file
import json
with open(os.path.join(new_path, 'second_stage_video_filtered_data_dict.json'), 'w') as f:
    json.dump(filtered_data_dict, f)

# %% [markdown]
# ## VAE extraction code testing

# %%
# %%
# Import necessary packages
import os
import json
import cv2
import torch
import numpy as np
from tqdm import tqdm
from pathlib import Path
from diffusers import AutoencoderKLCogVideoX
import decord
from decord import VideoReader
from multiprocessing import Process, Queue, Value

# %%
def process_video(queue, progress_queue, vae_model_path, max_frames, width, height, gpu_id, output_dir, fps):
    """
    Process videos assigned to a specific GPU.
    """
    device = f"cuda:{gpu_id}"

    # Load the VAE model
    vae = AutoencoderKLCogVideoX.from_pretrained(vae_model_path, subfolder="vae")
    vae.to(device)
    vae.eval()

    while True:
        path_and_fps = queue.get()
        if video_path is None:  # End signal
            break
        video_path, original_fps = path_and_fps

        try:
            # Load video using Decord
            decord.bridge.set_bridge("native")
            vr = VideoReader(video_path, ctx=decord.cpu(0))

            # Calculate frame interval
            original_fps = float(original_fps)
            frame_interval = int(original_fps / fps)

            # Extract frames
            # frames = vr.get_batch(range(0, min(len(vr), max_frames * frame_interval), frame_interval)).asnumpy()
            frames = vr.get_batch(range(0, min(len(vr), max_frames * frame_interval), frame_interval)).asnumpy()

            # Ensure exact number of frames
            if frames.shape[0] < max_frames:
                pad_frames = max_frames - frames.shape[0]
                print('>> shorter than max_frames : doing padding')
                frames = np.pad(frames, ((0, pad_frames), (0, 0), (0, 0), (0, 0)), mode="constant")
            elif frames.shape[0] > max_frames:
                frames = frames[:max_frames]
            # Resize frames using OpenCV
            frames = np.array([cv2.resize(frame, (width, height), interpolation=cv2.INTER_LINEAR) for frame in frames])

            # Convert to torch tensor and preprocess
            frames = torch.from_numpy(frames).float() / 255.0 * 2.0 - 1.0  # Normalize [-1, 1]
            frames = frames.permute(0, 3, 1, 2)  # [F, H, W, C] -> [F, C, H, W]
            
            # Add batch dimension and permute for VAE
            frames = frames.unsqueeze(0).permute(0, 2, 1, 3, 4).to(device)  # [B, C, F, H, W]

            # Encode video to latent space
            with torch.no_grad():
                latent_dist = vae.encode(frames).latent_dist
                latents = latent_dist.sample() * vae.config.scaling_factor

            # Save latents
            output_path = os.path.join(output_dir, Path(video_path).stem + "_vae_latents.npy")
            np.save(output_path, latents.cpu().numpy())

        except Exception as e:
            print(f"Error processing video {video_path}: {e}")

        # Clear GPU memory
        torch.cuda.empty_cache()

        # Notify progress
        progress_queue.put(1)


def extract_vae_latents(
    video_dir, video_keys, vae_model_path, output_dir, height=480, width=720, max_frames=49, fps=8, video_dict=None,
):
    """
    Extract VAE latents using multiple GPUs with controlled processes.
    """
    os.makedirs(output_dir, exist_ok=True)

    # Detect available GPUs
    available_gpus = list(range(torch.cuda.device_count()))
    if not available_gpus:
        raise RuntimeError("No GPUs are available!")

    print(f"Using GPUs: {available_gpus}")

    # Create a process for each GPU
    queues = [Queue() for _ in available_gpus]
    progress_queue = Queue()
    processes = []

    for gpu_id, queue in zip(available_gpus, queues):
        process = Process(target=process_video, args=(queue, progress_queue, vae_model_path, max_frames, width, height, gpu_id, output_dir, fps))
        process.start()
        processes.append(process)

    # Get video paths and original FPS pairs
    video_paths = [os.path.join(video_dir, vid_id + '.mp4') for vid_id in sorted(video_keys)]
    video_fps = [video_dict[vid_id]['fps'] for vid_id in sorted(video_keys)]
    # Distribute videos to queues
    for i, path_and_fps in enumerate(zip(video_paths, video_fps)):
        
        queues[i % len(available_gpus)].put(path_and_fps)

    # Send termination signals
    for queue in queues:
        queue.put(None)

    # Track progress using tqdm
    with tqdm(total=len(video_paths), desc="Extracting VAE latents") as pbar:
        completed = 0
        while completed < len(video_paths):
            progress_queue.get()  # Wait for progress notification
            completed += 1
            pbar.update(1)

    # Wait for all processes to finish
    for process in processes:
        process.join()

# %%
if __name__ == "__main__":
    import multiprocessing
    multiprocessing.set_start_method('spawn', True)

    json_dir = os.path.join(new_path, 'second_stage_video_filtered_data_dict.json')

    with open(json_dir, "r") as f:
        video_dict = json.load(f)

    video_keys = list(video_dict.keys())

    # Random sample 4K videos
    import random
    random.seed(42)
    video_keys = random.sample(video_keys, 4000)
    new_path = '/mnt/carpedkm_data/image_gen_ds/second_stage_video_train'
    # save the sampled video json file
    with open(os.path.join(new_path, 'second_stage_video_filtered_data_dict_sampled_4k.json'), 'w') as f:
        json.dump({k: video_dict[k] for k in video_keys}, f)
        
    video_dir = '/mnt/video_data/'
    vae_model_path = "THUDM/CogVideoX-5b"
    output_dir = "/mnt/carpedkm_data/image_gen_ds/second_stage_video_train_pexels"
    video_paths = [str(Path(video_dir) / f"{video_key}.mp4") for video_key in video_keys]
    extract_vae_latents(
            video_dir,
            video_keys,
            vae_model_path,
            output_dir,
            height=480,
            width=720,
            max_frames=25,
            fps=16,
            video_dict=video_dict,
        )
# Out:
# Using GPUs: [0, 1, 2, 3]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process_video' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process_video' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process_video' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/opt/conda/envs/ptca/lib/python3.10/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
# AttributeError: Can't get attribute 'process_video' on <module '__main__' (built-in)>
# Extracting VAE latents:   0%|          | 0/4000 [00:25<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 24
#      22 output_dir = "/mnt/carpedkm_data/image_gen_ds/second_stage_video_train_pexels"
#      23 video_paths = [str(Path(video_dir) / f"{video_key}.mp4") for video_key in video_keys]
# ---> 24 extract_vae_latents(
#      25         video_dir,
#      26         video_keys,
#      27         vae_model_path,
#      28         output_dir,
#      29         height=480,
#      30         width=720,
#      31         max_frames=25,
#      32         fps=16,
#      33         video_dict=video_dict,
#      34     )
#
# Cell In[67], line 108, in extract_vae_latents(video_dir, video_keys, vae_model_path, output_dir, height, width, max_frames, fps, video_dict)
#     106 completed = 0
#     107 while completed < len(video_paths):
# --> 108     progress_queue.get()  # Wait for progress notification
#     109     completed += 1
#     110     pbar.update(1)
#
# File /opt/conda/envs/ptca/lib/python3.10/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File /opt/conda/envs/ptca/lib/python3.10/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /opt/conda/envs/ptca/lib/python3.10/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File /opt/conda/envs/ptca/lib/python3.10/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     377 remaining = size
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#     381     if n == 0:
#
# KeyboardInterrupt:
