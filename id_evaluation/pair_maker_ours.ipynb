# %%
import os

# %%
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_original_0.2"
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_image_only_evalset"
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_first_frame_in_i2v_only"
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_t2v_only"
video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_wo_ref_token"
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_i2v_only"
prompt_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/zs_prompts.json"
first_frame_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/processed_white_720x480"

# %%
video_list = os.listdir(video_quanti_path)

# %%
image_list = os.listdir(first_frame_path)

# %%
# match video and image and make json like {
#     "000000129445.mp4": "000000129445.jpg",
#     "000000201436.mp4": "000000201436.jpg"
# }
vid_to_img_dict = {}
for vid in video_list:
    id_ = vid[43:-35]
    image_id = id_ + ".png"
    vid_to_img_dict[vid] = image_id

# %%
vid[43:-35]
# Out:
# 'custom_doll'

# %%
import json
with open('ours_wo_ref_token_vid_to_img.json', 'w') as f:
    json.dump(vid_to_img_dict, f, indent=4)

# %%
# load in prompt json
with open(prompt_path, 'r') as f:
    prompt_dict = json.load(f)

# %%
vid[-34:-4]
# Out:
# 'A_teddy_bear_is_playing_guitar'

# %%
# match prompt and image and make json like {
#     "000000129445.mp4": "A cat is sitting in a cozy kitchen, playfully pawing at a small object on the floor. The background shows wooden cabinets and a stainless steel refrigerator, with warm lighting creating a homely atmosphere. The cat occasionally looks around, its tail flicking back and forth.",
#     "000000201436.mp4": "A bottle sits on a wooden kitchen counter, illuminated by the warm glow of a nearby lamp. The camera slowly pans around, capturing the cozy ambiance of the kitchen, with a window showing a serene evening sky in the background. The bottle reflects the light, creating a soft, inviting atmosphere."
# }
vid_to_prompt_dict = {}
for vid in video_list:
    vid_prompt_order = vid.split(".")[0].split("_")[-1]
    vid_name_to_img_name = vid[43:-35]
    # prompt matching
    query_p = ' '.join(vid[-34:-4].split('_'))
    print(query_p)
    if vid_name_to_img_name in prompt_dict:
        for idx, p in enumerate(prompt_dict[vid_name_to_img_name]):
            if query_p in p:
                print(f"query_p: {query_p}")
                print(f"vid_name_to_img_name: {vid_name_to_img_name}")
                print(vid_prompt_order)
                break
        vid_to_prompt_dict[vid] = prompt_dict[vid_name_to_img_name][idx]
# Out:
# A pig dancing in a field of co
# query_p: A pig dancing in a field of co
# vid_name_to_img_name: stmv_pig
# co
# A white fox moves gracefully t
# query_p: A white fox moves gracefully t
# vid_name_to_img_name: chosen_whitefox
# t
# A guitar sits in the corner of
# query_p: A guitar sits in the corner of
# vid_name_to_img_name: custom_guitar
# of
# In a cozy living room, a white
# query_p: In a cozy living room, a white
# vid_name_to_img_name: stmv_hedgehog
# white
# A fox stands on a rocky cliff,
# query_p: A fox stands on a rocky cliff,
# vid_name_to_img_name: chosen_fox
# cliff,
# A corgi runs along the beach,
# query_p: A corgi runs along the beach,
# vid_name_to_img_name: dr_corgi
#
#  A pig surfing on a blue wave.
# A panda plush toy climbs a woo
# query_p: A panda plush toy climbs a woo
# vid_name_to_img_name: custom_panda
# woo
# A white hedgehog swinging on a
# query_p: A white hedgehog swinging on a
# vid_name_to_img_name: stmv_hedgehog
# a
# A dog flies through the sky, s
# query_p: A dog flies through the sky, s
# vid_name_to_img_name: dr_dog
# s
# A close-up view. A bowl of ora
# query_p: A close-up view. A bowl of ora
# vid_name_to_img_name: dr_orange
# view
# A wolf toy bounces on a child
# Under the open sky, a man is p
# query_p: Under the open sky, a man is p
# vid_name_to_img_name: custom_guitar
# p
# A pink toy sits on a child s n
# On a busy office desk, a tumbl
# query_p: On a busy office desk, a tumbl
# vid_name_to_img_name: custom_tumbler
# tumbl
# A pink toy floats in a bubble-
# query_p: A pink toy floats in a bubble-
# vid_name_to_img_name: custom_pinkdoll
# bubble-
# A water bottle floats weightle
# query_p: A water bottle floats weightle
# vid_name_to_img_name: chosen_water_bottle
# weightle
# A fox dashes through a dense f
# query_p: A fox dashes through a dense f
# vid_name_to_img_name: chosen_fox
# f
# A water bottle sits on a woode
# query_p: A water bottle sits on a woode
# vid_name_to_img_name: chosen_water_bottle
# woode
# A fox sneaks through a moonlit
# query_p: A fox sneaks through a moonlit
# vid_name_to_img_name: chosen_fox
# moonlit
# In a bustling cafe s, a clock
# A white dog toy dashes across
# query_p: A white dog toy dashes across
# vid_name_to_img_name: stmv_whitedog
#
# Under the neon glow of the cit
# query_p: Under the neon glow of the cit
# vid_name_to_img_name: chosen_bluecar
# cit
# A vase sits on a windowsill, f
# query_p: A vase sits on a windowsill, f
# vid_name_to_img_name: custom_vase
# f
# A bowl of oranges sits on a pi
# query_p: A bowl of oranges sits on a pi
# vid_name_to_img_name: dr_orange
# pi
# In a playful moment, a pig bou
# query_p: In a playful moment, a pig bou
# vid_name_to_img_name: stmv_pig
# bou
# A cat playfully pounces on a r
# query_p: A cat playfully pounces on a r
# vid_name_to_img_name: dr_cat
# r
# A cat scurries across a kitche
# query_p: A cat scurries across a kitche
# vid_name_to_img_name: stmv_pinkcat
# kitche
# A white fox cautiously steps o
# query_p: A white fox cautiously steps o
# vid_name_to_img_name: chosen_whitefox
# o
# Under the warm afternoon sun,
# query_p: Under the warm afternoon sun,
# vid_name_to_img_name: stmv_pinkcat
#
# A white dog toy bounces excite
# query_p: A white dog toy bounces excite
# vid_name_to_img_name: stmv_whitedog
# excite
# Beside an open book, a vase re
# query_p: Beside an open book, a vase re
# vid_name_to_img_name: custom_vase
# re
# A penguin toy stands on a wood
# query_p: A penguin toy stands on a wood
# vid_name_to_img_name: custom_penguin
# wood
# Under the dim glow of fairy li
# query_p: Under the dim glow of fairy li
# vid_name_to_img_name: dr_dog_toy
# li
# A pig eagerly chases a butterf
# query_p: A pig eagerly chases a butterf
# vid_name_to_img_name: stmv_pig
# butterf
# In the middle of a bustling pa
# query_p: In the middle of a bustling pa
# vid_name_to_img_name: dr_dog
# pa
# A clock rests on a wooden shel
# query_p: A clock rests on a wooden shel
# vid_name_to_img_name: dr_clock
# shel
# In the middle of the park, a c
# query_p: In the middle of the park, a c
# vid_name_to_img_name: dr_corgi
# c
# A panda plush toy is eating ba
# query_p: A panda plush toy is eating ba
# vid_name_to_img_name: custom_panda
# ba
# A clock sits on a glass table
# query_p: A clock sits on a glass table
# vid_name_to_img_name: dr_clock
#
# On a rainy evening, a cat sits
# query_p: On a rainy evening, a cat sits
# vid_name_to_img_name: dr_cat
# sits
# A teddy bear is running on a c
# query_p: A teddy bear is running on a c
# vid_name_to_img_name: custom_doll
# c
# A tumbler is placed on the pas
# query_p: A tumbler is placed on the pas
# vid_name_to_img_name: custom_tumbler
# pas
# Snow falls gently as a fox cau
# query_p: Snow falls gently as a fox cau
# vid_name_to_img_name: chosen_fox
# cau
# Oranges tumble out of a bowl,
# query_p: Oranges tumble out of a bowl,
# vid_name_to_img_name: dr_orange
#
# A white fox dashes through a b
# query_p: A white fox dashes through a b
# vid_name_to_img_name: chosen_whitefox
# b
# A white hedgehog rolls into a
# query_p: A white hedgehog rolls into a
# vid_name_to_img_name: stmv_hedgehog
#
# A cat rollerblading in a green
# query_p: A cat rollerblading in a green
# vid_name_to_img_name: stmv_pinkcat
# green
# A wolf toy dashes across a vas
# query_p: A wolf toy dashes across a vas
# vid_name_to_img_name: dr_dog_toy
# vas
# Dust rises as a blue car speed
# query_p: Dust rises as a blue car speed
# vid_name_to_img_name: chosen_bluecar
# speed
# A backpack sits on a train sea
# query_p: A backpack sits on a train sea
# vid_name_to_img_name: dr_backpack
# sea
# A backpack leaned against the
# query_p: A backpack leaned against the
# vid_name_to_img_name: dr_backpack
#
# A tumbler lies on a picnic bla
# query_p: A tumbler lies on a picnic bla
# vid_name_to_img_name: custom_tumbler
# bla
# A cat happily cuddled in a com
# query_p: A cat happily cuddled in a com
# vid_name_to_img_name: stmv_pinkcat
# com
# A teddy bear floats in a batht
# query_p: A teddy bear floats in a batht
# vid_name_to_img_name: custom_doll
# batht
# A white fox stands on a rocky
# query_p: A white fox stands on a rocky
# vid_name_to_img_name: chosen_whitefox
#
# At a cozy fireplace, a corgi c
# query_p: At a cozy fireplace, a corgi c
# vid_name_to_img_name: dr_corgi
# c
# On a snowy windowsill, a pengu
# query_p: On a snowy windowsill, a pengu
# vid_name_to_img_name: custom_penguin
# pengu
# A penguin toy sits on a child
# A bowl of oranges rests on a k
# query_p: A bowl of oranges rests on a k
# vid_name_to_img_name: dr_orange
# k
# A man has the vase in his hand
# query_p: A man has the vase in his hand
# vid_name_to_img_name: custom_vase
# hand
# A panda plush toy rolls down a
# query_p: A panda plush toy rolls down a
# vid_name_to_img_name: custom_panda
# a
# A panda plush toy is sitting o
# query_p: A panda plush toy is sitting o
# vid_name_to_img_name: custom_panda
# o
# A white dog toy shakes off wat
# query_p: A white dog toy shakes off wat
# vid_name_to_img_name: stmv_whitedog
# wat
# A water bottle rolls across th
# query_p: A water bottle rolls across th
# vid_name_to_img_name: chosen_water_bottle
# th
# A white hedgehog skiing down a
# query_p: A white hedgehog skiing down a
# vid_name_to_img_name: stmv_hedgehog
# a
# A tumbler sits on a wooden caf
# query_p: A tumbler sits on a wooden caf
# vid_name_to_img_name: custom_tumbler
# caf
# A pink toy is tucked inside a
# query_p: A pink toy is tucked inside a
# vid_name_to_img_name: custom_pinkdoll
#
# A dog sprints across a grassy
# query_p: A dog sprints across a grassy
# vid_name_to_img_name: dr_dog
#
# A corgi sits on the porch, wag
# query_p: A corgi sits on the porch, wag
# vid_name_to_img_name: dr_corgi
# wag
# A cat stretches on a sunlit wi
# query_p: A cat stretches on a sunlit wi
# vid_name_to_img_name: dr_cat
# wi
# A blue car races along a coast
# query_p: A blue car races along a coast
# vid_name_to_img_name: chosen_bluecar
# coast
# A water bottle stands on a gym
# query_p: A water bottle stands on a gym
# vid_name_to_img_name: chosen_water_bottle
# gym
# Rain pours heavily as a blue c
# query_p: Rain pours heavily as a blue c
# vid_name_to_img_name: chosen_bluecar
# c
# On a rainy afternoon, a pink t
# query_p: On a rainy afternoon, a pink t
# vid_name_to_img_name: custom_pinkdoll
# t
# A skilled musician is masterfu
# query_p: A skilled musician is masterfu
# vid_name_to_img_name: custom_guitar
# masterfu
# A wolf toy rolls off a park be
# query_p: A wolf toy rolls off a park be
# vid_name_to_img_name: dr_dog_toy
# be
# In the center of the dining ta
# query_p: In the center of the dining ta
# vid_name_to_img_name: custom_vase
# ta
# Inside a teddy bear store, a t
# query_p: Inside a teddy bear store, a t
# vid_name_to_img_name: custom_doll
# t
# On a quiet nightstand, a clock
# query_p: On a quiet nightstand, a clock
# vid_name_to_img_name: dr_clock
# clock
# A dog races through the waves
# query_p: A dog races through the waves
# vid_name_to_img_name: dr_dog
#
# A man is wearing backpack at h
# query_p: A man is wearing backpack at h
# vid_name_to_img_name: dr_backpack
# h
# A man holds the backpack at hi
# query_p: A man holds the backpack at hi
# vid_name_to_img_name: dr_backpack
# hi
# With ears perked up, a white d
# query_p: With ears perked up, a white d
# vid_name_to_img_name: stmv_whitedog
# d
# A guitar is played by a man on
# query_p: A guitar is played by a man on
# vid_name_to_img_name: custom_guitar
# on
# A cat glides effortlessly on r
# query_p: A cat glides effortlessly on r
# vid_name_to_img_name: dr_cat
# r
# A penguin toy floats in a bath
# query_p: A penguin toy floats in a bath
# vid_name_to_img_name: custom_penguin
# bath
# A teddy bear is playing guitar
# query_p: A teddy bear is playing guitar
# vid_name_to_img_name: custom_doll
# guitar

# %%
with open('ours_wo_ref_token_vid_to_prompt.json', 'w') as f:
    json.dump(vid_to_prompt_dict, f, indent=4)
