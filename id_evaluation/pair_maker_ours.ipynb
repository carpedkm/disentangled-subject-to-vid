# %%
import os

# %%
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_original_0.2"
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_image_only_evalset"
video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_first_frame_in_i2v_only"
# video_quanti_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/ours_i2v_only"
prompt_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/zs_prompts.json"
first_frame_path = "/root/daneul/projects/refactored/CogVideo/id_evaluation/processed_white_720x480"

# %%
video_list = os.listdir(video_quanti_path)

# %%
image_list = os.listdir(first_frame_path)

# %%
# match video and image and make json like {
#     "000000129445.mp4": "000000129445.jpg",
#     "000000201436.mp4": "000000201436.jpg"
# }
vid_to_img_dict = {}
for vid in video_list:
    id_ = vid[43:-35]
    image_id = id_ + ".png"
    vid_to_img_dict[vid] = image_id

# %%
import json
with open('ours_i2v_onours_first_frame_in_i2v_only_vid_to_img.json', 'w') as f:
    json.dump(vid_to_img_dict, f, indent=4)

# %%
# load in prompt json
with open(prompt_path, 'r') as f:
    prompt_dict = json.load(f)

# %%
# match prompt and image and make json like {
#     "000000129445.mp4": "A cat is sitting in a cozy kitchen, playfully pawing at a small object on the floor. The background shows wooden cabinets and a stainless steel refrigerator, with warm lighting creating a homely atmosphere. The cat occasionally looks around, its tail flicking back and forth.",
#     "000000201436.mp4": "A bottle sits on a wooden kitchen counter, illuminated by the warm glow of a nearby lamp. The camera slowly pans around, capturing the cozy ambiance of the kitchen, with a window showing a serene evening sky in the background. The bottle reflects the light, creating a soft, inviting atmosphere."
# }
vid_to_prompt_dict = {}
for vid in video_list:
    vid_prompt_order = vid.split(".")[0].split("_")[-1]
    vid_name_to_img_name = vid[43:-35]
    # prompt matching
    query_p = ' '.join(vid[-28:-4].split('_'))
    if vid_name_to_img_name in prompt_dict:
        for idx, p in enumerate(prompt_dict[vid_name_to_img_name]):
            if query_p in p:
                print(f"query_p: {query_p}")
                print(f"vid_name_to_img_name: {vid_name_to_img_name}")
                print(vid_prompt_order)
                break
        vid_to_prompt_dict[vid] = prompt_dict[vid_name_to_img_name][idx]
# Out:
# query_p: A cup is brought by a ma
# vid_name_to_img_name: custom_cup
# ma
# query_p: A group of friends laugh
# vid_name_to_img_name: custom_dice
# laugh
# query_p: A tumbler sits on a wood
# vid_name_to_img_name: custom_tumbler
# wood
# query_p: Under the dim glow of fa
# vid_name_to_img_name: dr_dog_toy
# fa
# query_p: Inside a teddy bear stor
# vid_name_to_img_name: custom_doll
# stor
# query_p: A dog races through the
# vid_name_to_img_name: dr_dog
#
# query_p: A pig dancing in a field
# vid_name_to_img_name: stmv_pig
# field
# query_p: A penguin toy sits on a
# vid_name_to_img_name: custom_penguin
#
# query_p: A bag sits on a bustling
# vid_name_to_img_name: chosen_purplebag
# bustling
# query_p: A fox sneaks through a m
# vid_name_to_img_name: chosen_fox
# m
# query_p: On a wooden fence, a squ
# vid_name_to_img_name: stmv_squirrel
# squ
# query_p: A white dog toy shakes o
# vid_name_to_img_name: stmv_whitedog
# o
# query_p: A white fox moves gracef
# vid_name_to_img_name: chosen_whitefox
# gracef
# query_p: A cat stretches on a sun
# vid_name_to_img_name: dr_cat
# sun
# query_p: A man holds the backpack
# vid_name_to_img_name: dr_backpack
# backpack
# query_p: A blue car races along a
# vid_name_to_img_name: chosen_bluecar
# a
# query_p: A man is wearing backpac
# vid_name_to_img_name: dr_backpack
# backpac
# query_p: A cat happily cuddled in
# vid_name_to_img_name: stmv_pinkcat
# in
# query_p: A guitar is played by a
# vid_name_to_img_name: custom_guitar
#
# query_p: In the middle of the roo
# vid_name_to_img_name: dr_red_toy
# roo
# query_p: Under dim candlelight, a
# vid_name_to_img_name: custom_dice
# a
# query_p: A cat rollerblading in a
# vid_name_to_img_name: stmv_pinkcat
# a
# query_p: A water bottle rolls acr
# vid_name_to_img_name: chosen_water_bottle
# acr
# query_p: In the middle of a bustl
# vid_name_to_img_name: dr_dog
# bustl
# query_p: A panda plush toy climbs
# vid_name_to_img_name: custom_panda
# climbs
# query_p: A woman wearing a Hawaii
# vid_name_to_img_name: dr_shirts
# Hawaii
# query_p: On the beach, a lady sit
# vid_name_to_img_name: dr_shirts
# sit
# query_p: A cup sits on a picnic b
# vid_name_to_img_name: custom_cup
# b
# query_p: In the middle of the par
# vid_name_to_img_name: dr_corgi
# par
# query_p: A vase sits on a windows
# vid_name_to_img_name: custom_vase
# windows
# query_p: Under the open sky, a ma
# vid_name_to_img_name: custom_guitar
# ma
# query_p: At a cozy fireplace, a c
# vid_name_to_img_name: dr_corgi
# c
# query_p: A cup sits on a wooden c
# vid_name_to_img_name: custom_cup
# c
# query_p: Dice plush tumble throug
# vid_name_to_img_name: custom_dice
# throug
# query_p: A white fox cautiously s
# vid_name_to_img_name: chosen_whitefox
# s
# query_p: A cat is sitting in a ca
# vid_name_to_img_name: custom_cat
# ca
# query_p: A toy car skids around a
# vid_name_to_img_name: dr_toycar
# a
# query_p: A cat curls up next to a
# vid_name_to_img_name: custom_cat
# a
# query_p: A bag swings from a trav
# vid_name_to_img_name: chosen_purplebag
# trav
# query_p: A pig eagerly chases a b
# vid_name_to_img_name: stmv_pig
# b
# query_p: A cat cautiously steps t
# vid_name_to_img_name: custom_cat
# t
# query_p: A pink toy floats in a b
# vid_name_to_img_name: custom_pinkdoll
# b
# query_p: A corgi runs along the b
# vid_name_to_img_name: dr_corgi
# b
# query_p: A pink toy sits on a chi
# vid_name_to_img_name: custom_pinkdoll
# chi
# query_p: A penguin toy stands on
# vid_name_to_img_name: custom_penguin
#
# query_p: Dust rises as a blue car
# vid_name_to_img_name: chosen_bluecar
# car
# query_p: In a playful moment, a p
# vid_name_to_img_name: stmv_pig
# p
# query_p: A red toy sits quietly o
# vid_name_to_img_name: dr_red_toy
# o
# query_p: A teddy bear floats in a
# vid_name_to_img_name: custom_doll
# a
# query_p: A water bottle stands on
# vid_name_to_img_name: chosen_water_bottle
# on
# query_p: On a snowy windowsill, a
# vid_name_to_img_name: custom_penguin
# a
# query_p: A skilled musician is ma
# vid_name_to_img_name: custom_guitar
# ma
# query_p: A wolf toy bounces on a
# vid_name_to_img_name: dr_dog_toy
#
# query_p: A bag rests on a wooden
# vid_name_to_img_name: chosen_purplebag
#
# query_p: A cat glides effortlessl
# vid_name_to_img_name: dr_cat
# effortlessl
# query_p: A dog flies through the
# vid_name_to_img_name: dr_dog
#
# query_p: In the center of the din
# vid_name_to_img_name: custom_vase
# din
# query_p: A white fox stands on a
# vid_name_to_img_name: chosen_whitefox
#
# query_p: A clock sits on a glass
# vid_name_to_img_name: dr_clock
#
# query_p: A water bottle sits on a
# vid_name_to_img_name: chosen_water_bottle
# a
# query_p: Under the warm afternoon
# vid_name_to_img_name: stmv_pinkcat
# afternoon
# query_p: A guitar sits in the cor
# vid_name_to_img_name: custom_guitar
# cor
# query_p: On a rainy evening, a ca
# vid_name_to_img_name: dr_cat
# ca
# query_p: A girl throws the dice p
# vid_name_to_img_name: custom_dice
# p
# query_p: Rain pours heavily as a
# vid_name_to_img_name: chosen_bluecar
#
# query_p: A panda plush toy is eat
# vid_name_to_img_name: custom_panda
# eat
# query_p: A close-up view. A bowl
# vid_name_to_img_name: dr_orange
# view
# query_p: A panda plush toy rolls
# vid_name_to_img_name: custom_panda
#
# query_p: Under the neon glow of t
# vid_name_to_img_name: chosen_bluecar
# t
# query_p: A wolf toy dashes across
# vid_name_to_img_name: dr_dog_toy
# across
# query_p: A man has the vase in hi
# vid_name_to_img_name: custom_vase
# hi
# query_p: A teddy bear is running
# vid_name_to_img_name: custom_doll
#
# query_p: A squirrel leaps between
# vid_name_to_img_name: stmv_squirrel
# between
# query_p: With ears perked up, a w
# vid_name_to_img_name: stmv_whitedog
# w
# query_p: A penguin toy floats in
# vid_name_to_img_name: custom_penguin
#
# query_p: A toy car races across a
# vid_name_to_img_name: dr_toycar
# a
# query_p: A bag falls onto a sandy
# vid_name_to_img_name: chosen_purplebag
# sandy
# query_p: A bowl of oranges sits o
# vid_name_to_img_name: dr_orange
# o
# query_p: A bowl of oranges rests
# vid_name_to_img_name: dr_orange
#
# query_p: A dog sprints across a g
# vid_name_to_img_name: dr_dog
# g
# query_p: A water bottle floats we
# vid_name_to_img_name: chosen_water_bottle
# we
# query_p: On a busy office desk, a
# vid_name_to_img_name: custom_tumbler
# a
# query_p: A white hedgehog rolls i
# vid_name_to_img_name: stmv_hedgehog
# i
# query_p: A cat scurries across a
# vid_name_to_img_name: stmv_pinkcat
#
# query_p: A white fox dashes throu
# vid_name_to_img_name: chosen_whitefox
# throu
# query_p: A red toy dances in the
# vid_name_to_img_name: dr_red_toy
#
# query_p: A tumbler is placed on t
# vid_name_to_img_name: custom_tumbler
# t
# query_p: On a quiet nightstand, a
# vid_name_to_img_name: dr_clock
# a
# query_p: A white hedgehog skiing
# vid_name_to_img_name: stmv_hedgehog
#
# query_p: A white dog toy bounces
# vid_name_to_img_name: stmv_whitedog
#
# query_p: A corgi sits on the porc
# vid_name_to_img_name: dr_corgi
# porc
# query_p: A white dog toy dashes a
# vid_name_to_img_name: stmv_whitedog
# a
# query_p: A pink toy is tucked ins
# vid_name_to_img_name: custom_pinkdoll
# ins
# query_p: A cat playfully pounces
# vid_name_to_img_name: dr_cat
#
# query_p: A tumbler lies on a picn
# vid_name_to_img_name: custom_tumbler
# picn
# query_p: A panda plush toy is sit
# vid_name_to_img_name: custom_panda
# sit
# query_p: A backpack leaned agains
# vid_name_to_img_name: dr_backpack
# agains
# query_p: A fox stands on a rocky
# vid_name_to_img_name: chosen_fox
#
# query_p: A white hedgehog swingin
# vid_name_to_img_name: stmv_hedgehog
# swingin
# query_p: At a tropical party, a g
# vid_name_to_img_name: dr_shirts
# g
# query_p: A squirrel scurries up a
# vid_name_to_img_name: stmv_squirrel
# a
# query_p: Beside an open book, a v
# vid_name_to_img_name: custom_vase
# v
# query_p: A teddy bear is playing
# vid_name_to_img_name: custom_doll
#
# query_p: Oranges tumble out of a
# vid_name_to_img_name: dr_orange
#
# query_p: A cat is lying on a fluf
# vid_name_to_img_name: custom_cat
# fluf
# query_p: A film-style shot. On th
# vid_name_to_img_name: dr_toycar
# shot
# query_p: Music plays loudly as a
# vid_name_to_img_name: dr_red_toy
#
# query_p: A fox dashes through a d
# vid_name_to_img_name: chosen_fox
# d
# query_p: Snow falls gently as a f
# vid_name_to_img_name: chosen_fox
# f
# query_p: A cup rests on a desk ne
# vid_name_to_img_name: custom_cup
# ne
# query_p: In the middle of a park,
# vid_name_to_img_name: stmv_squirrel
# park,
# query_p: A wolf toy rolls off a p
# vid_name_to_img_name: dr_dog_toy
# p
# query_p: In a cozy living room, a
# vid_name_to_img_name: stmv_hedgehog
# a
# query_p: A clock rests on a woode
# vid_name_to_img_name: dr_clock
# woode
# query_p: Under the glow of a stre
# vid_name_to_img_name: dr_toycar
# stre
# query_p: On a rainy afternoon, a
# vid_name_to_img_name: custom_pinkdoll
#
# query_p: A backpack sits on a tra
# vid_name_to_img_name: dr_backpack
# tra

# %%
video_list
# Out:
# ['ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cup_<cls>_A_cup_is_brought_by_a_ma.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_dice_<cls>_A_group_of_friends_laugh.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_tumbler_<cls>_A_tumbler_sits_on_a_wood.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_toy_<cls>_Under_the_dim_glow_of_fa.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_doll_<cls>_Inside_a_teddy_bear_stor.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_<cls>_A_dog_races_through_the_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pig_<cls>_A_pig_dancing_in_a_field.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_penguin_<cls>_A_penguin_toy_sits_on_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pig_<cls>_A_pig_surfing_on_a_blue_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_purplebag_<cls>_A_bag_sits_on_a_bustling.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_fox_<cls>_A_fox_sneaks_through_a_m.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_squirrel_<cls>_On_a_wooden_fence,_a_squ.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_whitedog_<cls>_A_white_dog_toy_shakes_o.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_whitefox_<cls>_A_white_fox_moves_gracef.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_cat_<cls>_A_cat_stretches_on_a_sun.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_backpack_<cls>_A_man_holds_the_backpack.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_bluecar_<cls>_A_blue_car_races_along_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_backpack_<cls>_A_man_is_wearing_backpac.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pinkcat_<cls>_A_cat_happily_cuddled_in.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_guitar_<cls>_A_guitar_is_played_by_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_red_toy_<cls>_In_the_middle_of_the_roo.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_dice_<cls>_Under_dim_candlelight,_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pinkcat_<cls>_A_cat_rollerblading_in_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_water_bottle_<cls>_A_water_bottle_rolls_acr.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_<cls>_In_the_middle_of_a_bustl.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_panda_<cls>_A_panda_plush_toy_climbs.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_shirts_<cls>_A_woman_wearing_a_Hawaii.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_shirts_<cls>_On_the_beach,_a_lady_sit.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cup_<cls>_A_cup_sits_on_a_picnic_b.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_corgi_<cls>_In_the_middle_of_the_par.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_vase_<cls>_A_vase_sits_on_a_windows.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_guitar_<cls>_Under_the_open_sky,_a_ma.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_corgi_<cls>_At_a_cozy_fireplace,_a_c.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cup_<cls>_A_cup_sits_on_a_wooden_c.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_dice_<cls>_Dice_plush_tumble_throug.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_whitefox_<cls>_A_white_fox_cautiously_s.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cat_<cls>_A_cat_is_sitting_in_a_ca.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_toycar_<cls>_A_toy_car_skids_around_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cat_<cls>_A_cat_curls_up_next_to_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_purplebag_<cls>_A_bag_swings_from_a_trav.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pig_<cls>_A_pig_eagerly_chases_a_b.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cat_<cls>_A_cat_cautiously_steps_t.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_pinkdoll_<cls>_A_pink_toy_floats_in_a_b.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_corgi_<cls>_A_corgi_runs_along_the_b.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_pinkdoll_<cls>_A_pink_toy_sits_on_a_chi.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_penguin_<cls>_A_penguin_toy_stands_on_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_bluecar_<cls>_Dust_rises_as_a_blue_car.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pig_<cls>_In_a_playful_moment,_a_p.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_red_toy_<cls>_A_red_toy_sits_quietly_o.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_doll_<cls>_A_teddy_bear_floats_in_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_water_bottle_<cls>_A_water_bottle_stands_on.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_penguin_<cls>_On_a_snowy_windowsill,_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_guitar_<cls>_A_skilled_musician_is_ma.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_toy_<cls>_A_wolf_toy_bounces_on_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_purplebag_<cls>_A_bag_rests_on_a_wooden_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_cat_<cls>_A_cat_glides_effortlessl.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_<cls>_A_dog_flies_through_the_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_vase_<cls>_In_the_center_of_the_din.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_whitefox_<cls>_A_white_fox_stands_on_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_clock_<cls>_A_clock_sits_on_a_glass_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_water_bottle_<cls>_A_water_bottle_sits_on_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pinkcat_<cls>_Under_the_warm_afternoon.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_guitar_<cls>_A_guitar_sits_in_the_cor.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_cat_<cls>_On_a_rainy_evening,_a_ca.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_dice_<cls>_A_girl_throws_the_dice_p.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_bluecar_<cls>_Rain_pours_heavily_as_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_panda_<cls>_A_panda_plush_toy_is_eat.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_orange_<cls>_A_close-up_view._A_bowl_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_panda_<cls>_A_panda_plush_toy_rolls_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_bluecar_<cls>_Under_the_neon_glow_of_t.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_toy_<cls>_A_wolf_toy_dashes_across.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_vase_<cls>_A_man_has_the_vase_in_hi.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_doll_<cls>_A_teddy_bear_is_running_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_squirrel_<cls>_A_squirrel_leaps_between.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_whitedog_<cls>_With_ears_perked_up,_a_w.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_penguin_<cls>_A_penguin_toy_floats_in_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_toycar_<cls>_A_toy_car_races_across_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_purplebag_<cls>_A_bag_falls_onto_a_sandy.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_orange_<cls>_A_bowl_of_oranges_sits_o.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_orange_<cls>_A_bowl_of_oranges_rests_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_<cls>_A_dog_sprints_across_a_g.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_water_bottle_<cls>_A_water_bottle_floats_we.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_tumbler_<cls>_On_a_busy_office_desk,_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_hedgehog_<cls>_A_white_hedgehog_rolls_i.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_pinkcat_<cls>_A_cat_scurries_across_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_whitefox_<cls>_A_white_fox_dashes_throu.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_red_toy_<cls>_A_red_toy_dances_in_the_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_tumbler_<cls>_A_tumbler_is_placed_on_t.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_clock_<cls>_On_a_quiet_nightstand,_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_hedgehog_<cls>_A_white_hedgehog_skiing_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_whitedog_<cls>_A_white_dog_toy_bounces_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_corgi_<cls>_A_corgi_sits_on_the_porc.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_whitedog_<cls>_A_white_dog_toy_dashes_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_pinkdoll_<cls>_A_pink_toy_is_tucked_ins.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_cat_<cls>_A_cat_playfully_pounces_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_tumbler_<cls>_A_tumbler_lies_on_a_picn.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_panda_<cls>_A_panda_plush_toy_is_sit.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_backpack_<cls>_A_backpack_leaned_agains.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_fox_<cls>_A_fox_stands_on_a_rocky_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_hedgehog_<cls>_A_white_hedgehog_swingin.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_shirts_<cls>_At_a_tropical_party,_a_g.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_squirrel_<cls>_A_squirrel_scurries_up_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_vase_<cls>_Beside_an_open_book,_a_v.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_doll_<cls>_A_teddy_bear_is_playing_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_orange_<cls>_Oranges_tumble_out_of_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cat_<cls>_A_cat_is_lying_on_a_fluf.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_toycar_<cls>_A_film-style_shot._On_th.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_red_toy_<cls>_Music_plays_loudly_as_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_fox_<cls>_A_fox_dashes_through_a_d.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_chosen_fox_<cls>_Snow_falls_gently_as_a_f.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_cup_<cls>_A_cup_rests_on_a_desk_ne.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_squirrel_<cls>_In_the_middle_of_a_park,.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_dog_toy_<cls>_A_wolf_toy_rolls_off_a_p.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_stmv_hedgehog_<cls>_In_a_cozy_living_room,_a.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_clock_<cls>_A_clock_rests_on_a_woode.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_toycar_<cls>_Under_the_glow_of_a_stre.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_custom_pinkdoll_<cls>_On_a_rainy_afternoon,_a_.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_backpack_<cls>_A_backpack_sits_on_a_tra.mp4',
#  'ckpt_8000_white_test_video_0_max_n_f_49_id_dr_clock_<cls>_In_a_bustling_cafe_s,_a_.mp4']

# %%
prompt_dict[vid_name_to_img_name][vid_prompt_order]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 prompt_dict[vid_name_to_img_name][vid_prompt_order]
#
# TypeError: list indices must be integers or slices, not str

# %%
with open('ours_first_frame_in_i2v_only_vid_to_prompt.json', 'w') as f:
    json.dump(vid_to_prompt_dict, f, indent=4)
